# %% [markdown]
# http://surpriselib.com

# %% [markdown]
# # Load data

# %%
from surprise import Dataset

data = Dataset.load_builtin('ml-100k')

# %% [markdown]
# # Manual pipeline

# %% [markdown]
# ## Split data in train and test

# %%
from surprise.model_selection import train_test_split

train, test = train_test_split(data, test_size=0.2, random_state=42)

# %%
test
# Out:
# [('907', '143', 5.0),
#  ('371', '210', 4.0),
#  ('218', '42', 4.0),
#  ('829', '170', 4.0),
#  ('733', '277', 1.0),
#  ('363', '1512', 1.0),
#  ('193', '487', 5.0),
#  ('808', '313', 5.0),
#  ('557', '682', 2.0),
#  ('774', '196', 3.0),
#  ('638', '118', 3.0),
#  ('632', '81', 5.0),
#  ('417', '200', 4.0),
#  ('580', '471', 3.0),
#  ('640', '91', 4.0),
#  ('450', '328', 4.0),
#  ('596', '13', 2.0),
#  ('586', '467', 4.0),
#  ('653', '502', 2.0),
#  ('378', '517', 3.0),
#  ('405', '65', 1.0),
#  ('279', '399', 4.0),
#  ('327', '293', 3.0),
#  ('346', '276', 1.0),
#  ('59', '928', 4.0),
#  ('514', '22', 4.0),
#  ('807', '402', 5.0),
#  ('473', '327', 3.0),
#  ('342', '324', 1.0),
#  ('269', '136', 4.0),
#  ('654', '1', 4.0),
#  ('250', '28', 4.0),
#  ('282', '689', 2.0),
#  ('534', '619', 4.0),
#  ('194', '481', 3.0),
#  ('184', '118', 2.0),
#  ('291', '739', 3.0),
#  ('293', '31', 2.0),
#  ('943', '1028', 2.0),
#  ('65', '69', 3.0),
#  ('562', '135', 5.0),
#  ('466', '62', 3.0),
#  ('847', '317', 3.0),
#  ('650', '521', 3.0),
#  ('656', '326', 1.0),
#  ('366', '53', 5.0),
#  ('15', '280', 3.0),
#  ('474', '322', 4.0),
#  ('90', '905', 4.0),
#  ('503', '19', 5.0),
#  ('334', '1524', 4.0),
#  ('90', '632', 5.0),
#  ('406', '1118', 3.0),
#  ('899', '515', 3.0),
#  ('13', '339', 3.0),
#  ('430', '19', 5.0),
#  ('24', '729', 5.0),
#  ('634', '225', 3.0),
#  ('727', '89', 5.0),
#  ('429', '596', 3.0),
#  ('62', '127', 4.0),
#  ('771', '241', 1.0),
#  ('733', '762', 4.0),
#  ('139', '222', 3.0),
#  ('916', '721', 4.0),
#  ('402', '204', 5.0),
#  ('553', '136', 4.0),
#  ('62', '1073', 4.0),
#  ('521', '271', 3.0),
#  ('488', '358', 3.0),
#  ('7', '231', 3.0),
#  ('346', '727', 1.0),
#  ('423', '823', 3.0),
#  ('405', '575', 5.0),
#  ('385', '1158', 5.0),
#  ('630', '125', 3.0),
#  ('551', '125', 4.0),
#  ('727', '183', 3.0),
#  ('660', '810', 3.0),
#  ('552', '323', 2.0),
#  ('13', '604', 5.0),
#  ('642', '812', 4.0),
#  ('240', '269', 5.0),
#  ('321', '191', 3.0),
#  ('85', '921', 3.0),
#  ('671', '161', 5.0),
#  ('253', '97', 4.0),
#  ('605', '187', 5.0),
#  ('472', '625', 4.0),
#  ('56', '449', 5.0),
#  ('881', '141', 3.0),
#  ('391', '318', 4.0),
#  ('601', '387', 3.0),
#  ('497', '475', 4.0),
#  ('327', '921', 4.0),
#  ('200', '1033', 2.0),
#  ('605', '64', 5.0),
#  ('796', '879', 4.0),
#  ('214', '216', 4.0),
#  ('566', '161', 4.0),
#  ('653', '423', 2.0),
#  ('344', '216', 4.0),
#  ('151', '664', 5.0),
#  ('64', '751', 2.0),
#  ('554', '87', 4.0),
#  ('384', '327', 4.0),
#  ('798', '1032', 3.0),
#  ('622', '90', 4.0),
#  ('719', '735', 5.0),
#  ('424', '740', 5.0),
#  ('294', '358', 2.0),
#  ('21', '396', 2.0),
#  ('690', '197', 4.0),
#  ('360', '471', 4.0),
#  ('734', '603', 4.0),
#  ('521', '174', 4.0),
#  ('484', '300', 4.0),
#  ('128', '50', 4.0),
#  ('633', '921', 3.0),
#  ('854', '466', 3.0),
#  ('493', '751', 5.0),
#  ('504', '392', 5.0),
#  ('655', '318', 4.0),
#  ('650', '157', 3.0),
#  ('104', '273', 3.0),
#  ('872', '117', 4.0),
#  ('276', '1170', 4.0),
#  ('146', '258', 4.0),
#  ('222', '1066', 1.0),
#  ('380', '199', 3.0),
#  ('618', '195', 3.0),
#  ('358', '1266', 4.0),
#  ('871', '813', 3.0),
#  ('234', '174', 3.0),
#  ('912', '15', 4.0),
#  ('75', '237', 2.0),
#  ('713', '270', 2.0),
#  ('251', '33', 3.0),
#  ('275', '199', 4.0),
#  ('766', '91', 5.0),
#  ('22', '204', 5.0),
#  ('487', '591', 2.0),
#  ('827', '316', 3.0),
#  ('919', '22', 5.0),
#  ('637', '274', 5.0),
#  ('666', '856', 5.0),
#  ('349', '458', 4.0),
#  ('880', '1197', 3.0),
#  ('30', '892', 4.0),
#  ('716', '213', 5.0),
#  ('235', '70', 5.0),
#  ('291', '1042', 4.0),
#  ('655', '311', 3.0),
#  ('387', '642', 4.0),
#  ('109', '31', 4.0),
#  ('484', '69', 5.0),
#  ('393', '7', 4.0),
#  ('314', '53', 1.0),
#  ('845', '1394', 4.0),
#  ('532', '311', 2.0),
#  ('195', '558', 3.0),
#  ('89', '151', 5.0),
#  ('824', '243', 1.0),
#  ('632', '11', 4.0),
#  ('393', '412', 3.0),
#  ('887', '121', 5.0),
#  ('682', '412', 1.0),
#  ('406', '210', 5.0),
#  ('795', '552', 2.0),
#  ('774', '546', 1.0),
#  ('47', '304', 3.0),
#  ('514', '15', 4.0),
#  ('804', '175', 4.0),
#  ('804', '1056', 4.0),
#  ('21', '243', 2.0),
#  ('618', '778', 3.0),
#  ('151', '222', 5.0),
#  ('224', '583', 1.0),
#  ('283', '709', 5.0),
#  ('504', '185', 5.0),
#  ('553', '135', 4.0),
#  ('846', '203', 5.0),
#  ('773', '52', 3.0),
#  ('385', '384', 1.0),
#  ('346', '720', 2.0),
#  ('373', '366', 4.0),
#  ('881', '474', 3.0),
#  ('537', '845', 2.0),
#  ('474', '50', 5.0),
#  ('293', '77', 2.0),
#  ('542', '435', 4.0),
#  ('262', '111', 4.0),
#  ('109', '1210', 3.0),
#  ('181', '1164', 3.0),
#  ('847', '96', 4.0),
#  ('625', '640', 3.0),
#  ('246', '178', 5.0),
#  ('425', '24', 2.0),
#  ('749', '712', 3.0),
#  ('586', '227', 2.0),
#  ('410', '754', 3.0),
#  ('332', '9', 4.0),
#  ('185', '47', 4.0),
#  ('582', '826', 3.0),
#  ('130', '217', 3.0),
#  ('537', '426', 1.0),
#  ('295', '380', 4.0),
#  ('756', '151', 4.0),
#  ('749', '826', 3.0),
#  ('405', '657', 1.0),
#  ('622', '1407', 1.0),
#  ('425', '825', 2.0),
#  ('372', '56', 4.0),
#  ('338', '1124', 4.0),
#  ('795', '568', 3.0),
#  ('99', '694', 1.0),
#  ('717', '980', 4.0),
#  ('470', '952', 3.0),
#  ('268', '153', 5.0),
#  ('425', '853', 4.0),
#  ('457', '566', 4.0),
#  ('73', '433', 4.0),
#  ('397', '665', 3.0),
#  ('466', '357', 4.0),
#  ('389', '1114', 2.0),
#  ('328', '903', 3.0),
#  ('378', '742', 4.0),
#  ('65', '211', 4.0),
#  ('333', '98', 4.0),
#  ('886', '240', 3.0),
#  ('897', '673', 5.0),
#  ('224', '720', 4.0),
#  ('934', '526', 2.0),
#  ('181', '931', 1.0),
#  ('839', '50', 5.0),
#  ('782', '322', 4.0),
#  ('181', '263', 1.0),
#  ('880', '40', 2.0),
#  ('505', '588', 5.0),
#  ('207', '433', 3.0),
#  ('500', '619', 3.0),
#  ('181', '360', 1.0),
#  ('922', '62', 3.0),
#  ('815', '735', 5.0),
#  ('782', '937', 1.0),
#  ('894', '638', 3.0),
#  ('551', '698', 4.0),
#  ('246', '1101', 5.0),
#  ('131', '275', 2.0),
#  ('606', '248', 5.0),
#  ('854', '191', 4.0),
#  ('889', '3', 4.0),
#  ('547', '294', 1.0),
#  ('211', '303', 3.0),
#  ('883', '707', 3.0),
#  ('823', '228', 3.0),
#  ('889', '173', 5.0),
#  ('293', '117', 3.0),
#  ('723', '164', 4.0),
#  ('313', '720', 2.0),
#  ('87', '8', 5.0),
#  ('305', '215', 2.0),
#  ('588', '1411', 1.0),
#  ('83', '50', 3.0),
#  ('81', '432', 2.0),
#  ('372', '77', 5.0),
#  ('409', '1512', 5.0),
#  ('194', '125', 2.0),
#  ('745', '510', 3.0),
#  ('749', '191', 4.0),
#  ('821', '117', 3.0),
#  ('552', '926', 2.0),
#  ('541', '659', 5.0),
#  ('682', '735', 4.0),
#  ('424', '127', 4.0),
#  ('854', '264', 1.0),
#  ('389', '492', 5.0),
#  ('354', '208', 4.0),
#  ('527', '127', 5.0),
#  ('378', '302', 5.0),
#  ('903', '1009', 4.0),
#  ('484', '15', 5.0),
#  ('62', '7', 4.0),
#  ('387', '692', 1.0),
#  ('641', '270', 3.0),
#  ('164', '9', 4.0),
#  ('608', '204', 4.0),
#  ('459', '472', 5.0),
#  ('566', '122', 2.0),
#  ('398', '4', 2.0),
#  ('407', '274', 3.0),
#  ('144', '273', 4.0),
#  ('523', '582', 4.0),
#  ('613', '607', 4.0),
#  ('416', '690', 5.0),
#  ('610', '317', 3.0),
#  ('758', '91', 4.0),
#  ('308', '58', 3.0),
#  ('334', '620', 2.0),
#  ('833', '506', 2.0),
#  ('70', '231', 3.0),
#  ('399', '1035', 3.0),
#  ('13', '64', 5.0),
#  ('534', '93', 1.0),
#  ('843', '708', 2.0),
#  ('639', '714', 2.0),
#  ('663', '321', 5.0),
#  ('189', '1402', 4.0),
#  ('457', '172', 5.0),
#  ('640', '580', 5.0),
#  ('94', '356', 4.0),
#  ('504', '187', 3.0),
#  ('436', '288', 4.0),
#  ('541', '1030', 3.0),
#  ('551', '168', 5.0),
#  ('703', '15', 5.0),
#  ('521', '228', 4.0),
#  ('510', '325', 1.0),
#  ('463', '689', 2.0),
#  ('312', '499', 4.0),
#  ('533', '357', 3.0),
#  ('393', '794', 4.0),
#  ('642', '748', 5.0),
#  ('851', '1291', 2.0),
#  ('128', '507', 4.0),
#  ('568', '653', 4.0),
#  ('325', '1', 2.0),
#  ('345', '161', 3.0),
#  ('741', '280', 3.0),
#  ('545', '222', 4.0),
#  ('778', '144', 4.0),
#  ('874', '137', 4.0),
#  ('897', '1254', 2.0),
#  ('385', '1143', 4.0),
#  ('487', '43', 3.0),
#  ('425', '269', 4.0),
#  ('758', '412', 5.0),
#  ('313', '191', 5.0),
#  ('11', '414', 3.0),
#  ('225', '1443', 4.0),
#  ('849', '676', 5.0),
#  ('616', '339', 3.0),
#  ('109', '131', 1.0),
#  ('548', '164', 5.0),
#  ('455', '1034', 2.0),
#  ('289', '849', 4.0),
#  ('896', '148', 2.0),
#  ('38', '294', 5.0),
#  ('194', '385', 2.0),
#  ('385', '235', 5.0),
#  ('553', '131', 5.0),
#  ('896', '184', 3.0),
#  ('940', '315', 4.0),
#  ('178', '144', 4.0),
#  ('482', '311', 4.0),
#  ('327', '663', 4.0),
#  ('601', '173', 5.0),
#  ('345', '150', 5.0),
#  ('761', '1014', 1.0),
#  ('790', '1119', 4.0),
#  ('489', '989', 3.0),
#  ('38', '318', 3.0),
#  ('279', '1496', 3.0),
#  ('923', '591', 5.0),
#  ('323', '215', 5.0),
#  ('376', '181', 4.0),
#  ('927', '541', 5.0),
#  ('416', '1286', 5.0),
#  ('268', '655', 4.0),
#  ('64', '196', 4.0),
#  ('271', '427', 5.0),
#  ('122', '511', 5.0),
#  ('167', '404', 3.0),
#  ('580', '281', 2.0),
#  ('95', '510', 4.0),
#  ('615', '237', 4.0),
#  ('663', '25', 4.0),
#  ('883', '517', 4.0),
#  ('189', '30', 4.0),
#  ('735', '333', 4.0),
#  ('711', '272', 5.0),
#  ('874', '124', 4.0),
#  ('796', '525', 4.0),
#  ('668', '596', 3.0),
#  ('533', '9', 4.0),
#  ('851', '248', 4.0),
#  ('360', '14', 5.0),
#  ('62', '181', 4.0),
#  ('579', '514', 3.0),
#  ('158', '745', 4.0),
#  ('119', '1052', 4.0),
#  ('275', '162', 3.0),
#  ('503', '277', 4.0),
#  ('710', '496', 4.0),
#  ('660', '550', 2.0),
#  ('42', '151', 4.0),
#  ('479', '147', 3.0),
#  ('574', '887', 4.0),
#  ('13', '655', 5.0),
#  ('593', '220', 3.0),
#  ('524', '526', 3.0),
#  ('244', '721', 5.0),
#  ('774', '567', 1.0),
#  ('848', '132', 5.0),
#  ('851', '435', 4.0),
#  ('198', '58', 3.0),
#  ('286', '210', 5.0),
#  ('608', '753', 5.0),
#  ('303', '379', 4.0),
#  ('271', '221', 3.0),
#  ('492', '650', 2.0),
#  ('782', '1278', 4.0),
#  ('864', '609', 3.0),
#  ('763', '357', 4.0),
#  ('894', '45', 4.0),
#  ('272', '201', 3.0),
#  ('264', '275', 5.0),
#  ('286', '278', 5.0),
#  ('190', '508', 3.0),
#  ('80', '194', 3.0),
#  ('916', '222', 3.0),
#  ('532', '495', 4.0),
#  ('929', '136', 3.0),
#  ('178', '731', 4.0),
#  ('327', '537', 4.0),
#  ('591', '172', 3.0),
#  ('679', '268', 4.0),
#  ('795', '429', 3.0),
#  ('234', '321', 2.0),
#  ('698', '275', 4.0),
#  ('385', '503', 3.0),
#  ('268', '746', 3.0),
#  ('682', '774', 4.0),
#  ('244', '287', 3.0),
#  ('387', '175', 5.0),
#  ('707', '194', 4.0),
#  ('216', '189', 3.0),
#  ('524', '523', 4.0),
#  ('486', '288', 4.0),
#  ('395', '252', 3.0),
#  ('620', '78', 4.0),
#  ('892', '64', 4.0),
#  ('345', '241', 4.0),
#  ('593', '597', 2.0),
#  ('895', '1', 4.0),
#  ('18', '237', 3.0),
#  ('60', '151', 5.0),
#  ('417', '39', 3.0),
#  ('823', '721', 4.0),
#  ('286', '231', 3.0),
#  ('389', '47', 4.0),
#  ('298', '1142', 4.0),
#  ('216', '200', 5.0),
#  ('236', '204', 3.0),
#  ('393', '808', 4.0),
#  ('704', '354', 4.0),
#  ('416', '1189', 5.0),
#  ('349', '696', 3.0),
#  ('90', '174', 5.0),
#  ('828', '1466', 4.0),
#  ('286', '1239', 3.0),
#  ('279', '275', 3.0),
#  ('451', '322', 4.0),
#  ('405', '959', 1.0),
#  ('718', '815', 4.0),
#  ('321', '116', 3.0),
#  ('334', '134', 5.0),
#  ('522', '12', 5.0),
#  ('889', '469', 4.0),
#  ('930', '282', 4.0),
#  ('215', '210', 4.0),
#  ('716', '603', 5.0),
#  ('326', '568', 4.0),
#  ('919', '287', 4.0),
#  ('344', '25', 4.0),
#  ('862', '650', 4.0),
#  ('153', '357', 5.0),
#  ('627', '521', 2.0),
#  ('901', '1120', 4.0),
#  ('868', '470', 1.0),
#  ('267', '47', 5.0),
#  ('361', '166', 4.0),
#  ('417', '217', 4.0),
#  ('459', '546', 1.0),
#  ('152', '22', 5.0),
#  ('625', '188', 4.0),
#  ('401', '294', 1.0),
#  ('160', '79', 4.0),
#  ('910', '100', 4.0),
#  ('179', '905', 4.0),
#  ('379', '502', 5.0),
#  ('796', '371', 5.0),
#  ('653', '163', 4.0),
#  ('746', '208', 4.0),
#  ('45', '284', 4.0),
#  ('766', '526', 2.0),
#  ('303', '578', 2.0),
#  ('898', '309', 5.0),
#  ('593', '866', 5.0),
#  ('643', '144', 4.0),
#  ('270', '747', 5.0),
#  ('474', '23', 4.0),
#  ('121', '237', 5.0),
#  ('479', '474', 5.0),
#  ('532', '771', 3.0),
#  ('121', '313', 5.0),
#  ('912', '268', 2.0),
#  ('764', '673', 4.0),
#  ('387', '1537', 4.0),
#  ('34', '288', 2.0),
#  ('344', '118', 3.0),
#  ('482', '127', 4.0),
#  ('456', '697', 4.0),
#  ('260', '748', 4.0),
#  ('305', '135', 3.0),
#  ('457', '114', 5.0),
#  ('339', '161', 3.0),
#  ('18', '702', 3.0),
#  ('918', '190', 5.0),
#  ('614', '14', 3.0),
#  ('470', '7', 3.0),
#  ('93', '934', 3.0),
#  ('407', '151', 4.0),
#  ('466', '173', 3.0),
#  ('279', '824', 4.0),
#  ('401', '185', 4.0),
#  ('779', '118', 5.0),
#  ('184', '629', 3.0),
#  ('102', '118', 3.0),
#  ('313', '636', 4.0),
#  ('232', '166', 4.0),
#  ('370', '427', 5.0),
#  ('320', '22', 5.0),
#  ('299', '1021', 3.0),
#  ('786', '230', 4.0),
#  ('867', '222', 4.0),
#  ('472', '386', 5.0),
#  ('826', '313', 5.0),
#  ('893', '412', 3.0),
#  ('757', '570', 3.0),
#  ('709', '431', 5.0),
#  ('705', '423', 2.0),
#  ('425', '187', 3.0),
#  ('268', '325', 3.0),
#  ('215', '474', 4.0),
#  ('9', '340', 4.0),
#  ('770', '742', 4.0),
#  ('762', '749', 1.0),
#  ('437', '248', 2.0),
#  ('13', '88', 4.0),
#  ('373', '196', 5.0),
#  ('429', '45', 3.0),
#  ('560', '7', 3.0),
#  ('123', '127', 5.0),
#  ('405', '226', 2.0),
#  ('756', '742', 3.0),
#  ('276', '665', 3.0),
#  ('63', '25', 4.0),
#  ('884', '198', 5.0),
#  ('653', '50', 5.0),
#  ('677', '288', 5.0),
#  ('561', '513', 3.0),
#  ('213', '294', 3.0),
#  ('188', '288', 4.0),
#  ('634', '866', 3.0),
#  ('896', '655', 4.0),
#  ('653', '223', 3.0),
#  ('817', '327', 4.0),
#  ('585', '855', 3.0),
#  ('782', '908', 3.0),
#  ('758', '234', 4.0),
#  ('295', '1459', 5.0),
#  ('655', '262', 5.0),
#  ('709', '227', 2.0),
#  ('64', '64', 4.0),
#  ('201', '289', 2.0),
#  ('291', '79', 5.0),
#  ('452', '94', 1.0),
#  ('474', '651', 5.0),
#  ('234', '1172', 3.0),
#  ('458', '275', 5.0),
#  ('927', '552', 4.0),
#  ('321', '1050', 3.0),
#  ('113', '303', 5.0),
#  ('706', '323', 4.0),
#  ('92', '527', 3.0),
#  ('83', '233', 4.0),
#  ('747', '419', 5.0),
#  ('234', '172', 3.0),
#  ('868', '568', 1.0),
#  ('372', '443', 4.0),
#  ('95', '716', 3.0),
#  ('97', '1', 4.0),
#  ('758', '1052', 5.0),
#  ('897', '443', 5.0),
#  ('320', '1011', 3.0),
#  ('279', '169', 5.0),
#  ('291', '1012', 4.0),
#  ('49', '10', 3.0),
#  ('738', '89', 5.0),
#  ('711', '403', 4.0),
#  ('524', '508', 5.0),
#  ('521', '651', 3.0),
#  ('633', '581', 3.0),
#  ('574', '213', 4.0),
#  ('878', '269', 4.0),
#  ('727', '38', 1.0),
#  ('610', '318', 5.0),
#  ('592', '461', 4.0),
#  ('562', '684', 4.0),
#  ('407', '8', 5.0),
#  ('938', '756', 3.0),
#  ('671', '327', 1.0),
#  ('731', '487', 4.0),
#  ('933', '227', 1.0),
#  ('805', '475', 5.0),
#  ('592', '345', 4.0),
#  ('389', '503', 3.0),
#  ('487', '92', 4.0),
#  ('932', '235', 2.0),
#  ('580', '1028', 3.0),
#  ('761', '1277', 1.0),
#  ('386', '181', 3.0),
#  ('145', '155', 2.0),
#  ('181', '148', 2.0),
#  ('618', '68', 3.0),
#  ('18', '474', 4.0),
#  ('672', '1190', 2.0),
#  ('399', '622', 4.0),
#  ('446', '302', 4.0),
#  ('848', '511', 4.0),
#  ('144', '262', 3.0),
#  ('660', '99', 2.0),
#  ('892', '1091', 2.0),
#  ('303', '164', 4.0),
#  ('417', '1210', 2.0),
#  ('421', '234', 5.0),
#  ('524', '382', 3.0),
#  ('290', '1091', 2.0),
#  ('18', '8', 5.0),
#  ('311', '785', 3.0),
#  ('727', '202', 4.0),
#  ('804', '615', 5.0),
#  ('579', '186', 3.0),
#  ('303', '1044', 3.0),
#  ('161', '204', 2.0),
#  ('320', '24', 3.0),
#  ('562', '806', 1.0),
#  ('10', '558', 4.0),
#  ('881', '49', 5.0),
#  ('738', '174', 5.0),
#  ('786', '684', 4.0),
#  ('23', '283', 4.0),
#  ('545', '393', 4.0),
#  ('608', '690', 4.0),
#  ('608', '333', 4.0),
#  ('194', '79', 3.0),
#  ('339', '53', 4.0),
#  ('162', '179', 3.0),
#  ('650', '117', 4.0),
#  ('442', '226', 3.0),
#  ('867', '28', 5.0),
#  ('435', '125', 3.0),
#  ('334', '19', 4.0),
#  ('804', '210', 5.0),
#  ('849', '421', 5.0),
#  ('543', '9', 4.0),
#  ('181', '620', 2.0),
#  ('889', '11', 5.0),
#  ('313', '231', 2.0),
#  ('801', '752', 4.0),
#  ('59', '433', 5.0),
#  ('563', '172', 5.0),
#  ('712', '462', 3.0),
#  ('159', '126', 5.0),
#  ('508', '70', 4.0),
#  ('653', '492', 4.0),
#  ('407', '588', 4.0),
#  ('293', '240', 2.0),
#  ('210', '243', 2.0),
#  ('765', '507', 5.0),
#  ('102', '1240', 2.0),
#  ('655', '286', 3.0),
#  ('618', '276', 3.0),
#  ('916', '474', 4.0),
#  ('943', '581', 4.0),
#  ('930', '100', 3.0),
#  ('271', '509', 4.0),
#  ('301', '771', 2.0),
#  ('7', '652', 3.0),
#  ('561', '642', 3.0),
#  ('84', '322', 3.0),
#  ('116', '270', 3.0),
#  ('334', '164', 3.0),
#  ('764', '77', 4.0),
#  ('737', '173', 4.0),
#  ('907', '173', 4.0),
#  ('805', '1033', 3.0),
#  ('141', '237', 4.0),
#  ('145', '1288', 4.0),
#  ('901', '560', 3.0),
#  ('588', '172', 5.0),
#  ('62', '288', 2.0),
#  ('62', '228', 3.0),
#  ('444', '751', 4.0),
#  ('450', '82', 3.0),
#  ('389', '386', 3.0),
#  ('567', '673', 3.0),
#  ('670', '232', 3.0),
#  ('756', '1074', 4.0),
#  ('387', '1011', 3.0),
#  ('447', '629', 3.0),
#  ('704', '519', 3.0),
#  ('653', '517', 1.0),
#  ('198', '381', 3.0),
#  ('899', '423', 4.0),
#  ('927', '257', 5.0),
#  ('91', '326', 3.0),
#  ('244', '156', 4.0),
#  ('943', '56', 5.0),
#  ('880', '186', 4.0),
#  ('843', '392', 2.0),
#  ('339', '97', 4.0),
#  ('199', '14', 4.0),
#  ('447', '926', 3.0),
#  ('629', '234', 4.0),
#  ('694', '528', 3.0),
#  ('314', '15', 5.0),
#  ('524', '116', 4.0),
#  ('432', '295', 3.0),
#  ('655', '340', 3.0),
#  ('334', '311', 4.0),
#  ('747', '408', 5.0),
#  ('506', '660', 3.0),
#  ('244', '710', 3.0),
#  ('276', '157', 5.0),
#  ('327', '88', 2.0),
#  ('702', '258', 5.0),
#  ('309', '324', 3.0),
#  ('37', '62', 5.0),
#  ('148', '172', 5.0),
#  ('417', '545', 1.0),
#  ('650', '301', 2.0),
#  ('94', '97', 4.0),
#  ('332', '12', 5.0),
#  ('536', '209', 2.0),
#  ('698', '220', 3.0),
#  ('151', '100', 3.0),
#  ('70', '496', 4.0),
#  ('268', '21', 3.0),
#  ('14', '70', 1.0),
#  ('690', '239', 2.0),
#  ('458', '589', 4.0),
#  ('7', '523', 4.0),
#  ('378', '793', 3.0),
#  ('297', '27', 1.0),
#  ('59', '208', 5.0),
#  ('18', '116', 5.0),
#  ('495', '1118', 5.0),
#  ('396', '245', 3.0),
#  ('837', '277', 2.0),
#  ('297', '102', 1.0),
#  ('846', '55', 5.0),
#  ('368', '441', 3.0),
#  ('643', '428', 4.0),
#  ('62', '245', 2.0),
#  ('383', '180', 5.0),
#  ('804', '1291', 3.0),
#  ('116', '300', 3.0),
#  ('632', '176', 3.0),
#  ('76', '264', 3.0),
#  ('704', '432', 5.0),
#  ('773', '268', 4.0),
#  ('413', '222', 4.0),
#  ('374', '69', 5.0),
#  ('201', '210', 2.0),
#  ('8', '172', 5.0),
#  ('327', '1012', 2.0),
#  ('326', '44', 1.0),
#  ('496', '156', 3.0),
#  ('296', '111', 3.0),
#  ('80', '260', 1.0),
#  ('682', '809', 2.0),
#  ('700', '98', 3.0),
#  ('293', '79', 3.0),
#  ('130', '761', 3.0),
#  ('524', '490', 3.0),
#  ('699', '762', 3.0),
#  ('730', '685', 2.0),
#  ('833', '144', 4.0),
#  ('777', '286', 2.0),
#  ('311', '498', 4.0),
#  ('314', '158', 3.0),
#  ('375', '302', 5.0),
#  ('60', '498', 5.0),
#  ('579', '4', 2.0),
#  ('537', '22', 2.0),
#  ('377', '200', 5.0),
#  ('828', '921', 4.0),
#  ('497', '139', 3.0),
#  ('591', '516', 3.0),
#  ('908', '194', 3.0),
#  ('198', '153', 4.0),
#  ('290', '683', 2.0),
#  ('815', '87', 5.0),
#  ('59', '237', 3.0),
#  ('422', '590', 2.0),
#  ('308', '71', 4.0),
#  ('394', '98', 5.0),
#  ('62', '98', 4.0),
#  ('829', '410', 3.0),
#  ('544', '343', 2.0),
#  ('617', '868', 4.0),
#  ('56', '71', 4.0),
#  ('429', '514', 3.0),
#  ('339', '1110', 4.0),
#  ('617', '669', 1.0),
#  ('549', '1047', 3.0),
#  ('647', '255', 4.0),
#  ('222', '1206', 2.0),
#  ('363', '739', 3.0),
#  ('291', '184', 4.0),
#  ('301', '271', 4.0),
#  ('118', '188', 5.0),
#  ('757', '1188', 3.0),
#  ('891', '280', 3.0),
#  ('565', '165', 4.0),
#  ('308', '81', 5.0),
#  ('530', '470', 3.0),
#  ('243', '93', 2.0),
#  ('59', '371', 4.0),
#  ('664', '1098', 3.0),
#  ('26', '760', 1.0),
#  ('830', '211', 4.0),
#  ('900', '9', 2.0),
#  ('864', '2', 4.0),
#  ('597', '242', 4.0),
#  ('22', '792', 4.0),
#  ('165', '270', 4.0),
#  ('483', '462', 3.0),
#  ('593', '144', 4.0),
#  ('299', '461', 3.0),
#  ('280', '237', 3.0),
#  ('327', '176', 4.0),
#  ('200', '196', 4.0),
#  ('264', '672', 3.0),
#  ('405', '48', 1.0),
#  ('429', '961', 3.0),
#  ('215', '164', 3.0),
#  ('569', '340', 4.0),
#  ('621', '804', 4.0),
#  ('188', '22', 5.0),
#  ('360', '144', 2.0),
#  ('293', '132', 4.0),
#  ('399', '343', 2.0),
#  ('456', '86', 2.0),
#  ('407', '157', 2.0),
#  ('707', '100', 5.0),
#  ('328', '750', 4.0),
#  ('488', '173', 4.0),
#  ('868', '229', 3.0),
#  ('151', '531', 3.0),
#  ('848', '523', 5.0),
#  ('454', '95', 2.0),
#  ('368', '7', 4.0),
#  ('807', '526', 5.0),
#  ('708', '15', 3.0),
#  ('845', '904', 3.0),
#  ('658', '471', 4.0),
#  ('328', '194', 3.0),
#  ('663', '473', 3.0),
#  ('537', '523', 3.0),
#  ('323', '1012', 4.0),
#  ('92', '834', 1.0),
#  ('161', '582', 1.0),
#  ('198', '568', 3.0),
#  ('650', '429', 4.0),
#  ('776', '708', 5.0),
#  ('617', '320', 5.0),
#  ('843', '121', 3.0),
#  ('196', '173', 2.0),
#  ('37', '273', 3.0),
#  ('402', '410', 1.0),
#  ('487', '1', 5.0),
#  ('133', '750', 4.0),
#  ('123', '23', 4.0),
#  ('788', '1248', 3.0),
#  ('606', '1280', 2.0),
#  ('151', '181', 5.0),
#  ('305', '338', 3.0),
#  ('889', '297', 3.0),
#  ('253', '294', 4.0),
#  ('553', '191', 4.0),
#  ('409', '1541', 4.0),
#  ('285', '150', 5.0),
#  ('77', '268', 5.0),
#  ('455', '1137', 3.0),
#  ('483', '313', 2.0),
#  ('84', '15', 4.0),
#  ('709', '739', 3.0),
#  ('579', '7', 3.0),
#  ('327', '709', 4.0),
#  ('805', '405', 3.0),
#  ('786', '86', 4.0),
#  ('334', '301', 2.0),
#  ('388', '773', 3.0),
#  ('222', '1419', 1.0),
#  ('151', '433', 3.0),
#  ('556', '187', 5.0),
#  ('850', '490', 5.0),
#  ('291', '41', 4.0),
#  ('846', '739', 4.0),
#  ('332', '97', 5.0),
#  ('388', '307', 4.0),
#  ('776', '134', 4.0),
#  ('642', '955', 3.0),
#  ('622', '402', 3.0),
#  ('890', '436', 3.0),
#  ('269', '640', 5.0),
#  ('6', '32', 4.0),
#  ('313', '155', 2.0),
#  ('417', '452', 2.0),
#  ('685', '299', 2.0),
#  ('469', '64', 5.0),
#  ('806', '455', 3.0),
#  ('370', '64', 4.0),
#  ('313', '582', 2.0),
#  ('303', '873', 3.0),
#  ('363', '39', 4.0),
#  ('882', '756', 3.0),
#  ('466', '909', 5.0),
#  ('59', '25', 4.0),
#  ('186', '588', 4.0),
#  ('735', '288', 4.0),
#  ('52', '288', 3.0),
#  ('624', '255', 3.0),
#  ('868', '378', 2.0),
#  ('847', '367', 3.0),
#  ('675', '347', 4.0),
#  ('210', '97', 5.0),
#  ('929', '654', 3.0),
#  ('631', '307', 4.0),
#  ('72', '382', 4.0),
#  ('276', '77', 3.0),
#  ('459', '286', 4.0),
#  ('727', '421', 5.0),
#  ('75', '137', 4.0),
#  ('486', '327', 3.0),
#  ('882', '432', 5.0),
#  ('919', '1284', 3.0),
#  ('149', '310', 2.0),
#  ('5', '454', 1.0),
#  ('548', '466', 5.0),
#  ('546', '977', 5.0),
#  ('87', '196', 5.0),
#  ('847', '1', 3.0),
#  ('579', '88', 4.0),
#  ('345', '956', 4.0),
#  ('327', '715', 4.0),
#  ('234', '1221', 4.0),
#  ('854', '479', 4.0),
#  ('807', '566', 4.0),
#  ('396', '472', 5.0),
#  ('719', '79', 4.0),
#  ('312', '740', 4.0),
#  ('436', '785', 2.0),
#  ('592', '881', 1.0),
#  ('624', '886', 4.0),
#  ('916', '2', 3.0),
#  ('95', '71', 5.0),
#  ('262', '567', 1.0),
#  ('606', '168', 5.0),
#  ('398', '235', 2.0),
#  ('321', '215', 3.0),
#  ('686', '2', 3.0),
#  ('619', '879', 4.0),
#  ('932', '659', 5.0),
#  ('308', '275', 4.0),
#  ('782', '1241', 2.0),
#  ('351', '751', 4.0),
#  ('269', '661', 4.0),
#  ('93', '118', 3.0),
#  ('425', '823', 3.0),
#  ('524', '310', 4.0),
#  ('618', '371', 3.0),
#  ('268', '182', 4.0),
#  ('324', '538', 4.0),
#  ('899', '740', 5.0),
#  ('87', '80', 4.0),
#  ('825', '925', 4.0),
#  ('378', '272', 4.0),
#  ('774', '135', 3.0),
#  ('930', '238', 4.0),
#  ('704', '604', 5.0),
#  ('854', '509', 4.0),
#  ('704', '185', 4.0),
#  ('497', '1407', 3.0),
#  ('429', '166', 5.0),
#  ('255', '597', 4.0),
#  ('406', '136', 4.0),
#  ...]

# %%
train.n_users, train.n_items
# Out:
# (943, 1651)

# %% [markdown]
# ## Train model

# %% [markdown]
# - Use 2 models : user & item based
# https://surprise.readthedocs.io/en/stable/knn_inspired.html

# %%
from surprise import SVD

model = SVD()

# %%
model.fit(train)

# %% [markdown]
# ## Make predictions

# %%
predictions = model.test(test)

# %%
predictions
# Out:
# [Prediction(uid='907', iid='143', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='371', iid='210', r_ui=4.0, est=4.191122865147293, details={'was_impossible': False}),
#  Prediction(uid='218', iid='42', r_ui=4.0, est=3.473083841095421, details={'was_impossible': False}),
#  Prediction(uid='829', iid='170', r_ui=4.0, est=3.949191067572329, details={'was_impossible': False}),
#  Prediction(uid='733', iid='277', r_ui=1.0, est=2.9758992679839533, details={'was_impossible': False}),
#  Prediction(uid='363', iid='1512', r_ui=1.0, est=3.205272170479884, details={'was_impossible': False}),
#  Prediction(uid='193', iid='487', r_ui=5.0, est=3.675045161329235, details={'was_impossible': False}),
#  Prediction(uid='808', iid='313', r_ui=5.0, est=4.731864584859961, details={'was_impossible': False}),
#  Prediction(uid='557', iid='682', r_ui=2.0, est=3.3218953362227355, details={'was_impossible': False}),
#  Prediction(uid='774', iid='196', r_ui=3.0, est=2.4977535694803823, details={'was_impossible': False}),
#  Prediction(uid='638', iid='118', r_ui=3.0, est=3.400036952738023, details={'was_impossible': False}),
#  Prediction(uid='632', iid='81', r_ui=5.0, est=3.4229732999170692, details={'was_impossible': False}),
#  Prediction(uid='417', iid='200', r_ui=4.0, est=3.5899300683998647, details={'was_impossible': False}),
#  Prediction(uid='580', iid='471', r_ui=3.0, est=3.6071252029050593, details={'was_impossible': False}),
#  Prediction(uid='640', iid='91', r_ui=4.0, est=4.2587531450611396, details={'was_impossible': False}),
#  Prediction(uid='450', iid='328', r_ui=4.0, est=3.9525528532424583, details={'was_impossible': False}),
#  Prediction(uid='596', iid='13', r_ui=2.0, est=3.597993558385535, details={'was_impossible': False}),
#  Prediction(uid='586', iid='467', r_ui=4.0, est=3.591167212051505, details={'was_impossible': False}),
#  Prediction(uid='653', iid='502', r_ui=2.0, est=2.671507242354495, details={'was_impossible': False}),
#  Prediction(uid='378', iid='517', r_ui=3.0, est=3.8232373683937375, details={'was_impossible': False}),
#  Prediction(uid='405', iid='65', r_ui=1.0, est=2.413917212566701, details={'was_impossible': False}),
#  Prediction(uid='279', iid='399', r_ui=4.0, est=3.168175316759475, details={'was_impossible': False}),
#  Prediction(uid='327', iid='293', r_ui=3.0, est=3.3038091941872527, details={'was_impossible': False}),
#  Prediction(uid='346', iid='276', r_ui=1.0, est=3.3187275526386144, details={'was_impossible': False}),
#  Prediction(uid='59', iid='928', r_ui=4.0, est=3.408749602517063, details={'was_impossible': False}),
#  Prediction(uid='514', iid='22', r_ui=4.0, est=4.213550638167159, details={'was_impossible': False}),
#  Prediction(uid='807', iid='402', r_ui=5.0, est=3.8878375633260935, details={'was_impossible': False}),
#  Prediction(uid='473', iid='327', r_ui=3.0, est=3.822306006409567, details={'was_impossible': False}),
#  Prediction(uid='342', iid='324', r_ui=1.0, est=2.717052795825282, details={'was_impossible': False}),
#  Prediction(uid='269', iid='136', r_ui=4.0, est=3.5341014465815888, details={'was_impossible': False}),
#  Prediction(uid='654', iid='1', r_ui=4.0, est=4.396665686464897, details={'was_impossible': False}),
#  Prediction(uid='250', iid='28', r_ui=4.0, est=4.085964099851048, details={'was_impossible': False}),
#  Prediction(uid='282', iid='689', r_ui=2.0, est=3.3482325345616792, details={'was_impossible': False}),
#  Prediction(uid='534', iid='619', r_ui=4.0, est=4.138494663008083, details={'was_impossible': False}),
#  Prediction(uid='194', iid='481', r_ui=3.0, est=3.200237764213432, details={'was_impossible': False}),
#  Prediction(uid='184', iid='118', r_ui=2.0, est=2.747202904146563, details={'was_impossible': False}),
#  Prediction(uid='291', iid='739', r_ui=3.0, est=3.35508153550664, details={'was_impossible': False}),
#  Prediction(uid='293', iid='31', r_ui=2.0, est=3.3643763972528964, details={'was_impossible': False}),
#  Prediction(uid='943', iid='1028', r_ui=2.0, est=2.6697227302072153, details={'was_impossible': False}),
#  Prediction(uid='65', iid='69', r_ui=3.0, est=4.279143885636806, details={'was_impossible': False}),
#  Prediction(uid='562', iid='135', r_ui=5.0, est=3.945562392252366, details={'was_impossible': False}),
#  Prediction(uid='466', iid='62', r_ui=3.0, est=2.8941308811222286, details={'was_impossible': False}),
#  Prediction(uid='847', iid='317', r_ui=3.0, est=3.304687587141884, details={'was_impossible': False}),
#  Prediction(uid='650', iid='521', r_ui=3.0, est=3.493288187247452, details={'was_impossible': False}),
#  Prediction(uid='656', iid='326', r_ui=1.0, est=2.6166746822896862, details={'was_impossible': False}),
#  Prediction(uid='366', iid='53', r_ui=5.0, est=3.4693254698433855, details={'was_impossible': False}),
#  Prediction(uid='15', iid='280', r_ui=3.0, est=2.794081767925347, details={'was_impossible': False}),
#  Prediction(uid='474', iid='322', r_ui=4.0, est=2.923557060057565, details={'was_impossible': False}),
#  Prediction(uid='90', iid='905', r_ui=4.0, est=4.02635775079654, details={'was_impossible': False}),
#  Prediction(uid='503', iid='19', r_ui=5.0, est=4.007238299962934, details={'was_impossible': False}),
#  Prediction(uid='334', iid='1524', r_ui=4.0, est=3.800940648757007, details={'was_impossible': False}),
#  Prediction(uid='90', iid='632', r_ui=5.0, est=4.382330632969742, details={'was_impossible': False}),
#  Prediction(uid='406', iid='1118', r_ui=3.0, est=3.3535726402746904, details={'was_impossible': False}),
#  Prediction(uid='899', iid='515', r_ui=3.0, est=4.029296930181008, details={'was_impossible': False}),
#  Prediction(uid='13', iid='339', r_ui=3.0, est=3.0449292284872675, details={'was_impossible': False}),
#  Prediction(uid='430', iid='19', r_ui=5.0, est=3.6770405241103976, details={'was_impossible': False}),
#  Prediction(uid='24', iid='729', r_ui=5.0, est=3.8921661672181136, details={'was_impossible': False}),
#  Prediction(uid='634', iid='225', r_ui=3.0, est=3.087334201107681, details={'was_impossible': False}),
#  Prediction(uid='727', iid='89', r_ui=5.0, est=4.045879872036107, details={'was_impossible': False}),
#  Prediction(uid='429', iid='596', r_ui=3.0, est=3.1413897934858643, details={'was_impossible': False}),
#  Prediction(uid='62', iid='127', r_ui=4.0, est=4.185840527292112, details={'was_impossible': False}),
#  Prediction(uid='771', iid='241', r_ui=1.0, est=3.1991740594751596, details={'was_impossible': False}),
#  Prediction(uid='733', iid='762', r_ui=4.0, est=3.148927686233623, details={'was_impossible': False}),
#  Prediction(uid='139', iid='222', r_ui=3.0, est=3.7695746015321685, details={'was_impossible': False}),
#  Prediction(uid='916', iid='721', r_ui=4.0, est=3.218530410125495, details={'was_impossible': False}),
#  Prediction(uid='402', iid='204', r_ui=5.0, est=3.9669147855292977, details={'was_impossible': False}),
#  Prediction(uid='553', iid='136', r_ui=4.0, est=4.27099299203852, details={'was_impossible': False}),
#  Prediction(uid='62', iid='1073', r_ui=4.0, est=3.4017664408855475, details={'was_impossible': False}),
#  Prediction(uid='521', iid='271', r_ui=3.0, est=3.0610410441141593, details={'was_impossible': False}),
#  Prediction(uid='488', iid='358', r_ui=3.0, est=2.2764505385634664, details={'was_impossible': False}),
#  Prediction(uid='7', iid='231', r_ui=3.0, est=2.8716235063826696, details={'was_impossible': False}),
#  Prediction(uid='346', iid='727', r_ui=1.0, est=3.2735247114611234, details={'was_impossible': False}),
#  Prediction(uid='423', iid='823', r_ui=3.0, est=3.187784737940259, details={'was_impossible': False}),
#  Prediction(uid='405', iid='575', r_ui=5.0, est=1, details={'was_impossible': False}),
#  Prediction(uid='385', iid='1158', r_ui=5.0, est=3.10249618616971, details={'was_impossible': False}),
#  Prediction(uid='630', iid='125', r_ui=3.0, est=3.6261388429693233, details={'was_impossible': False}),
#  Prediction(uid='551', iid='125', r_ui=4.0, est=3.565774539951754, details={'was_impossible': False}),
#  Prediction(uid='727', iid='183', r_ui=3.0, est=3.244352489461689, details={'was_impossible': False}),
#  Prediction(uid='660', iid='810', r_ui=3.0, est=1.8599184922597938, details={'was_impossible': False}),
#  Prediction(uid='552', iid='323', r_ui=2.0, est=2.7928729719876846, details={'was_impossible': False}),
#  Prediction(uid='13', iid='604', r_ui=5.0, est=3.5587759607694895, details={'was_impossible': False}),
#  Prediction(uid='642', iid='812', r_ui=4.0, est=3.27501622347305, details={'was_impossible': False}),
#  Prediction(uid='240', iid='269', r_ui=5.0, est=4.5986186498505734, details={'was_impossible': False}),
#  Prediction(uid='321', iid='191', r_ui=3.0, est=4.044333086937379, details={'was_impossible': False}),
#  Prediction(uid='85', iid='921', r_ui=3.0, est=3.797000105366292, details={'was_impossible': False}),
#  Prediction(uid='671', iid='161', r_ui=5.0, est=3.6923537080203905, details={'was_impossible': False}),
#  Prediction(uid='253', iid='97', r_ui=4.0, est=4.056315826424366, details={'was_impossible': False}),
#  Prediction(uid='605', iid='187', r_ui=5.0, est=4.692434409558974, details={'was_impossible': False}),
#  Prediction(uid='472', iid='625', r_ui=4.0, est=4.028574225350063, details={'was_impossible': False}),
#  Prediction(uid='56', iid='449', r_ui=5.0, est=3.3318574964483134, details={'was_impossible': False}),
#  Prediction(uid='881', iid='141', r_ui=3.0, est=3.369593530021008, details={'was_impossible': False}),
#  Prediction(uid='391', iid='318', r_ui=4.0, est=4.227863034071737, details={'was_impossible': False}),
#  Prediction(uid='601', iid='387', r_ui=3.0, est=2.835683854498735, details={'was_impossible': False}),
#  Prediction(uid='497', iid='475', r_ui=4.0, est=3.7505719389780556, details={'was_impossible': False}),
#  Prediction(uid='327', iid='921', r_ui=4.0, est=3.409693544033817, details={'was_impossible': False}),
#  Prediction(uid='200', iid='1033', r_ui=2.0, est=3.1902780682122684, details={'was_impossible': False}),
#  Prediction(uid='605', iid='64', r_ui=5.0, est=4.560504630947684, details={'was_impossible': False}),
#  Prediction(uid='796', iid='879', r_ui=4.0, est=3.4708221008423608, details={'was_impossible': False}),
#  Prediction(uid='214', iid='216', r_ui=4.0, est=4.024422100996972, details={'was_impossible': False}),
#  Prediction(uid='566', iid='161', r_ui=4.0, est=3.1101254314259608, details={'was_impossible': False}),
#  Prediction(uid='653', iid='423', r_ui=2.0, est=3.0098816660427303, details={'was_impossible': False}),
#  Prediction(uid='344', iid='216', r_ui=4.0, est=3.9250167296109453, details={'was_impossible': False}),
#  Prediction(uid='151', iid='664', r_ui=5.0, est=4.490552349193362, details={'was_impossible': False}),
#  Prediction(uid='64', iid='751', r_ui=2.0, est=3.1975383407896256, details={'was_impossible': False}),
#  Prediction(uid='554', iid='87', r_ui=4.0, est=3.877938331501087, details={'was_impossible': False}),
#  Prediction(uid='384', iid='327', r_ui=4.0, est=4.020305606631578, details={'was_impossible': False}),
#  Prediction(uid='798', iid='1032', r_ui=3.0, est=3.2187573254801225, details={'was_impossible': False}),
#  Prediction(uid='622', iid='90', r_ui=4.0, est=3.022392997221181, details={'was_impossible': False}),
#  Prediction(uid='719', iid='735', r_ui=5.0, est=3.1217434583258665, details={'was_impossible': False}),
#  Prediction(uid='424', iid='740', r_ui=5.0, est=3.0578279774063204, details={'was_impossible': False}),
#  Prediction(uid='294', iid='358', r_ui=2.0, est=2.9033775775050072, details={'was_impossible': False}),
#  Prediction(uid='21', iid='396', r_ui=2.0, est=2.45727287972193, details={'was_impossible': False}),
#  Prediction(uid='690', iid='197', r_ui=4.0, est=3.6566281988169687, details={'was_impossible': False}),
#  Prediction(uid='360', iid='471', r_ui=4.0, est=3.3211059776613108, details={'was_impossible': False}),
#  Prediction(uid='734', iid='603', r_ui=4.0, est=4.046895478478215, details={'was_impossible': False}),
#  Prediction(uid='521', iid='174', r_ui=4.0, est=3.6223993102672547, details={'was_impossible': False}),
#  Prediction(uid='484', iid='300', r_ui=4.0, est=4.254332661364306, details={'was_impossible': False}),
#  Prediction(uid='128', iid='50', r_ui=4.0, est=4.246893039063525, details={'was_impossible': False}),
#  Prediction(uid='633', iid='921', r_ui=3.0, est=3.642204575648223, details={'was_impossible': False}),
#  Prediction(uid='854', iid='466', r_ui=3.0, est=3.191500909923975, details={'was_impossible': False}),
#  Prediction(uid='493', iid='751', r_ui=5.0, est=3.625929342694822, details={'was_impossible': False}),
#  Prediction(uid='504', iid='392', r_ui=5.0, est=3.81849646931925, details={'was_impossible': False}),
#  Prediction(uid='655', iid='318', r_ui=4.0, est=4.038352940657583, details={'was_impossible': False}),
#  Prediction(uid='650', iid='157', r_ui=3.0, est=3.1347289203346547, details={'was_impossible': False}),
#  Prediction(uid='104', iid='273', r_ui=3.0, est=2.6767415695313987, details={'was_impossible': False}),
#  Prediction(uid='872', iid='117', r_ui=4.0, est=4.274049134489557, details={'was_impossible': False}),
#  Prediction(uid='276', iid='1170', r_ui=4.0, est=3.3121315977856205, details={'was_impossible': False}),
#  Prediction(uid='146', iid='258', r_ui=4.0, est=3.8211076402858373, details={'was_impossible': False}),
#  Prediction(uid='222', iid='1066', r_ui=1.0, est=2.9511310938391886, details={'was_impossible': False}),
#  Prediction(uid='380', iid='199', r_ui=3.0, est=3.579344950983957, details={'was_impossible': False}),
#  Prediction(uid='618', iid='195', r_ui=3.0, est=3.7298485920895317, details={'was_impossible': False}),
#  Prediction(uid='358', iid='1266', r_ui=4.0, est=3.2199159042085954, details={'was_impossible': False}),
#  Prediction(uid='871', iid='813', r_ui=3.0, est=3.9336454511114294, details={'was_impossible': False}),
#  Prediction(uid='234', iid='174', r_ui=3.0, est=3.864366532260769, details={'was_impossible': False}),
#  Prediction(uid='912', iid='15', r_ui=4.0, est=3.2371188105779267, details={'was_impossible': False}),
#  Prediction(uid='75', iid='237', r_ui=2.0, est=3.6546867701714225, details={'was_impossible': False}),
#  Prediction(uid='713', iid='270', r_ui=2.0, est=3.133522903352995, details={'was_impossible': False}),
#  Prediction(uid='251', iid='33', r_ui=3.0, est=3.477282577600464, details={'was_impossible': False}),
#  Prediction(uid='275', iid='199', r_ui=4.0, est=3.6859391401033905, details={'was_impossible': False}),
#  Prediction(uid='766', iid='91', r_ui=5.0, est=3.405730638934703, details={'was_impossible': False}),
#  Prediction(uid='22', iid='204', r_ui=5.0, est=3.920793826511427, details={'was_impossible': False}),
#  Prediction(uid='487', iid='591', r_ui=2.0, est=3.719541572315881, details={'was_impossible': False}),
#  Prediction(uid='827', iid='316', r_ui=3.0, est=4.160014889047172, details={'was_impossible': False}),
#  Prediction(uid='919', iid='22', r_ui=5.0, est=3.6381512291807763, details={'was_impossible': False}),
#  Prediction(uid='637', iid='274', r_ui=5.0, est=2.461529861180917, details={'was_impossible': False}),
#  Prediction(uid='666', iid='856', r_ui=5.0, est=3.830025173225008, details={'was_impossible': False}),
#  Prediction(uid='349', iid='458', r_ui=4.0, est=3.0397038868936437, details={'was_impossible': False}),
#  Prediction(uid='880', iid='1197', r_ui=3.0, est=3.5820313399131924, details={'was_impossible': False}),
#  Prediction(uid='30', iid='892', r_ui=4.0, est=2.928978061329162, details={'was_impossible': False}),
#  Prediction(uid='716', iid='213', r_ui=5.0, est=4.109532002369211, details={'was_impossible': False}),
#  Prediction(uid='235', iid='70', r_ui=5.0, est=3.346448376085627, details={'was_impossible': False}),
#  Prediction(uid='291', iid='1042', r_ui=4.0, est=3.351119350501856, details={'was_impossible': False}),
#  Prediction(uid='655', iid='311', r_ui=3.0, est=3.319040423513745, details={'was_impossible': False}),
#  Prediction(uid='387', iid='642', r_ui=4.0, est=3.083892722645426, details={'was_impossible': False}),
#  Prediction(uid='109', iid='31', r_ui=4.0, est=4.00693214088041, details={'was_impossible': False}),
#  Prediction(uid='484', iid='69', r_ui=5.0, est=4.708503134737448, details={'was_impossible': False}),
#  Prediction(uid='393', iid='7', r_ui=4.0, est=3.080514396034967, details={'was_impossible': False}),
#  Prediction(uid='314', iid='53', r_ui=1.0, est=2.684613634458316, details={'was_impossible': False}),
#  Prediction(uid='845', iid='1394', r_ui=4.0, est=2.6884715200520195, details={'was_impossible': False}),
#  Prediction(uid='532', iid='311', r_ui=2.0, est=4.279431497336825, details={'was_impossible': False}),
#  Prediction(uid='195', iid='558', r_ui=3.0, est=3.4641017857414442, details={'was_impossible': False}),
#  Prediction(uid='89', iid='151', r_ui=5.0, est=3.647710673929012, details={'was_impossible': False}),
#  Prediction(uid='824', iid='243', r_ui=1.0, est=2.1875520155682606, details={'was_impossible': False}),
#  Prediction(uid='632', iid='11', r_ui=4.0, est=3.7711801569463956, details={'was_impossible': False}),
#  Prediction(uid='393', iid='412', r_ui=3.0, est=1.791168693696683, details={'was_impossible': False}),
#  Prediction(uid='887', iid='121', r_ui=5.0, est=4.592939991283377, details={'was_impossible': False}),
#  Prediction(uid='682', iid='412', r_ui=1.0, est=2.432923529763906, details={'was_impossible': False}),
#  Prediction(uid='406', iid='210', r_ui=5.0, est=3.479395063334789, details={'was_impossible': False}),
#  Prediction(uid='795', iid='552', r_ui=2.0, est=2.9530048891215555, details={'was_impossible': False}),
#  Prediction(uid='774', iid='546', r_ui=1.0, est=1.5951333821794398, details={'was_impossible': False}),
#  Prediction(uid='47', iid='304', r_ui=3.0, est=3.6356024001847906, details={'was_impossible': False}),
#  Prediction(uid='514', iid='15', r_ui=4.0, est=4.2143114635668795, details={'was_impossible': False}),
#  Prediction(uid='804', iid='175', r_ui=4.0, est=3.8479932649527653, details={'was_impossible': False}),
#  Prediction(uid='804', iid='1056', r_ui=4.0, est=3.262429010209921, details={'was_impossible': False}),
#  Prediction(uid='21', iid='243', r_ui=2.0, est=1.6485165179609176, details={'was_impossible': False}),
#  Prediction(uid='618', iid='778', r_ui=3.0, est=3.447814243032029, details={'was_impossible': False}),
#  Prediction(uid='151', iid='222', r_ui=5.0, est=3.5994421221004376, details={'was_impossible': False}),
#  Prediction(uid='224', iid='583', r_ui=1.0, est=2.6081318328609506, details={'was_impossible': False}),
#  Prediction(uid='283', iid='709', r_ui=5.0, est=4.880823882356946, details={'was_impossible': False}),
#  Prediction(uid='504', iid='185', r_ui=5.0, est=4.232851780285803, details={'was_impossible': False}),
#  Prediction(uid='553', iid='135', r_ui=4.0, est=4.001385724370925, details={'was_impossible': False}),
#  Prediction(uid='846', iid='203', r_ui=5.0, est=4.013339139998752, details={'was_impossible': False}),
#  Prediction(uid='773', iid='52', r_ui=3.0, est=3.28738932499083, details={'was_impossible': False}),
#  Prediction(uid='385', iid='384', r_ui=1.0, est=2.4787866536468006, details={'was_impossible': False}),
#  Prediction(uid='346', iid='720', r_ui=2.0, est=2.9077038441794847, details={'was_impossible': False}),
#  Prediction(uid='373', iid='366', r_ui=4.0, est=3.677892043997843, details={'was_impossible': False}),
#  Prediction(uid='881', iid='474', r_ui=3.0, est=3.5688903940018193, details={'was_impossible': False}),
#  Prediction(uid='537', iid='845', r_ui=2.0, est=2.356286866040317, details={'was_impossible': False}),
#  Prediction(uid='474', iid='50', r_ui=5.0, est=4.73501493479567, details={'was_impossible': False}),
#  Prediction(uid='293', iid='77', r_ui=2.0, est=2.9210707526587947, details={'was_impossible': False}),
#  Prediction(uid='542', iid='435', r_ui=4.0, est=3.72551385731007, details={'was_impossible': False}),
#  Prediction(uid='262', iid='111', r_ui=4.0, est=3.2429692944926836, details={'was_impossible': False}),
#  Prediction(uid='109', iid='1210', r_ui=3.0, est=2.7761539021684625, details={'was_impossible': False}),
#  Prediction(uid='181', iid='1164', r_ui=3.0, est=1.3852469654043535, details={'was_impossible': False}),
#  Prediction(uid='847', iid='96', r_ui=4.0, est=3.557858415451298, details={'was_impossible': False}),
#  Prediction(uid='625', iid='640', r_ui=3.0, est=2.7654307084770995, details={'was_impossible': False}),
#  Prediction(uid='246', iid='178', r_ui=5.0, est=3.718433215407491, details={'was_impossible': False}),
#  Prediction(uid='425', iid='24', r_ui=2.0, est=3.4472148329617895, details={'was_impossible': False}),
#  Prediction(uid='749', iid='712', r_ui=3.0, est=3.324262048560785, details={'was_impossible': False}),
#  Prediction(uid='586', iid='227', r_ui=2.0, est=3.1553701005735206, details={'was_impossible': False}),
#  Prediction(uid='410', iid='754', r_ui=3.0, est=3.0064773591419027, details={'was_impossible': False}),
#  Prediction(uid='332', iid='9', r_ui=4.0, est=4.406445210308155, details={'was_impossible': False}),
#  Prediction(uid='185', iid='47', r_ui=4.0, est=3.863829452319793, details={'was_impossible': False}),
#  Prediction(uid='582', iid='826', r_ui=3.0, est=2.404715649747061, details={'was_impossible': False}),
#  Prediction(uid='130', iid='217', r_ui=3.0, est=4.086257222337594, details={'was_impossible': False}),
#  Prediction(uid='537', iid='426', r_ui=1.0, est=2.6460474015003235, details={'was_impossible': False}),
#  Prediction(uid='295', iid='380', r_ui=4.0, est=4.039894764223117, details={'was_impossible': False}),
#  Prediction(uid='756', iid='151', r_ui=4.0, est=3.156732613844044, details={'was_impossible': False}),
#  Prediction(uid='749', iid='826', r_ui=3.0, est=2.7418994562713292, details={'was_impossible': False}),
#  Prediction(uid='405', iid='657', r_ui=1.0, est=2.8059101420362573, details={'was_impossible': False}),
#  Prediction(uid='622', iid='1407', r_ui=1.0, est=2.7787172977575154, details={'was_impossible': False}),
#  Prediction(uid='425', iid='825', r_ui=2.0, est=2.499756316024758, details={'was_impossible': False}),
#  Prediction(uid='372', iid='56', r_ui=4.0, est=4.68874835340377, details={'was_impossible': False}),
#  Prediction(uid='338', iid='1124', r_ui=4.0, est=3.7082186592846913, details={'was_impossible': False}),
#  Prediction(uid='795', iid='568', r_ui=3.0, est=3.2424004820466092, details={'was_impossible': False}),
#  Prediction(uid='99', iid='694', r_ui=1.0, est=3.9651972465368375, details={'was_impossible': False}),
#  Prediction(uid='717', iid='980', r_ui=4.0, est=3.6483047576360765, details={'was_impossible': False}),
#  Prediction(uid='470', iid='952', r_ui=3.0, est=3.148655464776706, details={'was_impossible': False}),
#  Prediction(uid='268', iid='153', r_ui=5.0, est=3.4851634382284913, details={'was_impossible': False}),
#  Prediction(uid='425', iid='853', r_ui=4.0, est=3.5561024957400957, details={'was_impossible': False}),
#  Prediction(uid='457', iid='566', r_ui=4.0, est=4.0250287517819405, details={'was_impossible': False}),
#  Prediction(uid='73', iid='433', r_ui=4.0, est=3.4848631977229574, details={'was_impossible': False}),
#  Prediction(uid='397', iid='665', r_ui=3.0, est=2.6335007185300743, details={'was_impossible': False}),
#  Prediction(uid='466', iid='357', r_ui=4.0, est=3.9790405399976088, details={'was_impossible': False}),
#  Prediction(uid='389', iid='1114', r_ui=2.0, est=3.5920867584701988, details={'was_impossible': False}),
#  Prediction(uid='328', iid='903', r_ui=3.0, est=3.2574783108440895, details={'was_impossible': False}),
#  Prediction(uid='378', iid='742', r_ui=4.0, est=3.3515278873559025, details={'was_impossible': False}),
#  Prediction(uid='65', iid='211', r_ui=4.0, est=4.084644265587593, details={'was_impossible': False}),
#  Prediction(uid='333', iid='98', r_ui=4.0, est=4.35512030244605, details={'was_impossible': False}),
#  Prediction(uid='886', iid='240', r_ui=3.0, est=2.770383051705653, details={'was_impossible': False}),
#  Prediction(uid='897', iid='673', r_ui=5.0, est=3.766143091851741, details={'was_impossible': False}),
#  Prediction(uid='224', iid='720', r_ui=4.0, est=2.8809724971674977, details={'was_impossible': False}),
#  Prediction(uid='934', iid='526', r_ui=2.0, est=4.02332150116667, details={'was_impossible': False}),
#  Prediction(uid='181', iid='931', r_ui=1.0, est=1, details={'was_impossible': False}),
#  Prediction(uid='839', iid='50', r_ui=5.0, est=4.110442218152639, details={'was_impossible': False}),
#  Prediction(uid='782', iid='322', r_ui=4.0, est=2.6916465701183974, details={'was_impossible': False}),
#  Prediction(uid='181', iid='263', r_ui=1.0, est=1, details={'was_impossible': False}),
#  Prediction(uid='880', iid='40', r_ui=2.0, est=3.5187908848997953, details={'was_impossible': False}),
#  Prediction(uid='505', iid='588', r_ui=5.0, est=3.7774337184697875, details={'was_impossible': False}),
#  Prediction(uid='207', iid='433', r_ui=3.0, est=3.1115732225365482, details={'was_impossible': False}),
#  Prediction(uid='500', iid='619', r_ui=3.0, est=2.9271689805315053, details={'was_impossible': False}),
#  Prediction(uid='181', iid='360', r_ui=1.0, est=1.8556687733416917, details={'was_impossible': False}),
#  Prediction(uid='922', iid='62', r_ui=3.0, est=3.2537314411499922, details={'was_impossible': False}),
#  Prediction(uid='815', iid='735', r_ui=5.0, est=3.813296343079758, details={'was_impossible': False}),
#  Prediction(uid='782', iid='937', r_ui=1.0, est=2.979784501183565, details={'was_impossible': False}),
#  Prediction(uid='894', iid='638', r_ui=3.0, est=3.665371944392544, details={'was_impossible': False}),
#  Prediction(uid='551', iid='698', r_ui=4.0, est=3.662960214774464, details={'was_impossible': False}),
#  Prediction(uid='246', iid='1101', r_ui=5.0, est=3.2469476944863334, details={'was_impossible': False}),
#  Prediction(uid='131', iid='275', r_ui=2.0, est=4.109616234026354, details={'was_impossible': False}),
#  Prediction(uid='606', iid='248', r_ui=5.0, est=4.049604411904255, details={'was_impossible': False}),
#  Prediction(uid='854', iid='191', r_ui=4.0, est=4.10160549175302, details={'was_impossible': False}),
#  Prediction(uid='889', iid='3', r_ui=4.0, est=2.8932629753346704, details={'was_impossible': False}),
#  Prediction(uid='547', iid='294', r_ui=1.0, est=2.599672586455969, details={'was_impossible': False}),
#  Prediction(uid='211', iid='303', r_ui=3.0, est=3.0258780458736974, details={'was_impossible': False}),
#  Prediction(uid='883', iid='707', r_ui=3.0, est=4.031489786525384, details={'was_impossible': False}),
#  Prediction(uid='823', iid='228', r_ui=3.0, est=4.566353056858718, details={'was_impossible': False}),
#  Prediction(uid='889', iid='173', r_ui=5.0, est=4.122963582431827, details={'was_impossible': False}),
#  Prediction(uid='293', iid='117', r_ui=3.0, est=2.63134396915667, details={'was_impossible': False}),
#  Prediction(uid='723', iid='164', r_ui=4.0, est=3.3742258967872205, details={'was_impossible': False}),
#  Prediction(uid='313', iid='720', r_ui=2.0, est=2.7020428607561, details={'was_impossible': False}),
#  Prediction(uid='87', iid='8', r_ui=5.0, est=4.359106935024419, details={'was_impossible': False}),
#  Prediction(uid='305', iid='215', r_ui=2.0, est=3.439573736926458, details={'was_impossible': False}),
#  Prediction(uid='588', iid='1411', r_ui=1.0, est=3.2659386239522514, details={'was_impossible': False}),
#  Prediction(uid='83', iid='50', r_ui=3.0, est=4.327702206299393, details={'was_impossible': False}),
#  Prediction(uid='81', iid='432', r_ui=2.0, est=3.6153965295732235, details={'was_impossible': False}),
#  Prediction(uid='372', iid='77', r_ui=5.0, est=3.990546843890195, details={'was_impossible': False}),
#  Prediction(uid='409', iid='1512', r_ui=5.0, est=3.8440287581040247, details={'was_impossible': False}),
#  Prediction(uid='194', iid='125', r_ui=2.0, est=2.7900663538973802, details={'was_impossible': False}),
#  Prediction(uid='745', iid='510', r_ui=3.0, est=3.0895047235579054, details={'was_impossible': False}),
#  Prediction(uid='749', iid='191', r_ui=4.0, est=4.047459917058007, details={'was_impossible': False}),
#  Prediction(uid='821', iid='117', r_ui=3.0, est=4.400515045707181, details={'was_impossible': False}),
#  Prediction(uid='552', iid='926', r_ui=2.0, est=2.6593242031543616, details={'was_impossible': False}),
#  Prediction(uid='541', iid='659', r_ui=5.0, est=4.137338894234183, details={'was_impossible': False}),
#  Prediction(uid='682', iid='735', r_ui=4.0, est=3.2873254800903595, details={'was_impossible': False}),
#  Prediction(uid='424', iid='127', r_ui=4.0, est=3.7774597736743947, details={'was_impossible': False}),
#  Prediction(uid='854', iid='264', r_ui=1.0, est=1.9761461329142218, details={'was_impossible': False}),
#  Prediction(uid='389', iid='492', r_ui=5.0, est=3.8420783687138114, details={'was_impossible': False}),
#  Prediction(uid='354', iid='208', r_ui=4.0, est=3.519417953899953, details={'was_impossible': False}),
#  Prediction(uid='527', iid='127', r_ui=5.0, est=4.464136588620444, details={'was_impossible': False}),
#  Prediction(uid='378', iid='302', r_ui=5.0, est=3.9057416173991646, details={'was_impossible': False}),
#  Prediction(uid='903', iid='1009', r_ui=4.0, est=3.875089575892115, details={'was_impossible': False}),
#  Prediction(uid='484', iid='15', r_ui=5.0, est=4.101965378745319, details={'was_impossible': False}),
#  Prediction(uid='62', iid='7', r_ui=4.0, est=3.574682384558401, details={'was_impossible': False}),
#  Prediction(uid='387', iid='692', r_ui=1.0, est=2.369471237589657, details={'was_impossible': False}),
#  Prediction(uid='641', iid='270', r_ui=3.0, est=3.8023620732649683, details={'was_impossible': False}),
#  Prediction(uid='164', iid='9', r_ui=4.0, est=4.327420090588268, details={'was_impossible': False}),
#  Prediction(uid='608', iid='204', r_ui=4.0, est=3.5504945904001564, details={'was_impossible': False}),
#  Prediction(uid='459', iid='472', r_ui=5.0, est=3.3546787985738153, details={'was_impossible': False}),
#  Prediction(uid='566', iid='122', r_ui=2.0, est=2.3994108967396324, details={'was_impossible': False}),
#  Prediction(uid='398', iid='4', r_ui=2.0, est=3.728911691336501, details={'was_impossible': False}),
#  Prediction(uid='407', iid='274', r_ui=3.0, est=3.286787091604365, details={'was_impossible': False}),
#  Prediction(uid='144', iid='273', r_ui=4.0, est=3.321753168919307, details={'was_impossible': False}),
#  Prediction(uid='523', iid='582', r_ui=4.0, est=4.3143314674664195, details={'was_impossible': False}),
#  Prediction(uid='613', iid='607', r_ui=4.0, est=4.199893961317097, details={'was_impossible': False}),
#  Prediction(uid='416', iid='690', r_ui=5.0, est=3.8214342044123057, details={'was_impossible': False}),
#  Prediction(uid='610', iid='317', r_ui=3.0, est=3.8627687306095018, details={'was_impossible': False}),
#  Prediction(uid='758', iid='91', r_ui=4.0, est=4.532208499412131, details={'was_impossible': False}),
#  Prediction(uid='308', iid='58', r_ui=3.0, est=3.5816986025834705, details={'was_impossible': False}),
#  Prediction(uid='334', iid='620', r_ui=2.0, est=3.1157685485426247, details={'was_impossible': False}),
#  Prediction(uid='833', iid='506', r_ui=2.0, est=3.2270812205316672, details={'was_impossible': False}),
#  Prediction(uid='70', iid='231', r_ui=3.0, est=2.8457232348916865, details={'was_impossible': False}),
#  Prediction(uid='399', iid='1035', r_ui=3.0, est=2.640259301338573, details={'was_impossible': False}),
#  Prediction(uid='13', iid='64', r_ui=5.0, est=4.458275167102201, details={'was_impossible': False}),
#  Prediction(uid='534', iid='93', r_ui=1.0, est=4.501364142394928, details={'was_impossible': False}),
#  Prediction(uid='843', iid='708', r_ui=2.0, est=2.6677277902240557, details={'was_impossible': False}),
#  Prediction(uid='639', iid='714', r_ui=2.0, est=2.845838549659458, details={'was_impossible': False}),
#  Prediction(uid='663', iid='321', r_ui=5.0, est=2.9309854109252362, details={'was_impossible': False}),
#  Prediction(uid='189', iid='1402', r_ui=4.0, est=3.52340394590445, details={'was_impossible': False}),
#  Prediction(uid='457', iid='172', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='640', iid='580', r_ui=5.0, est=3.963959319247015, details={'was_impossible': False}),
#  Prediction(uid='94', iid='356', r_ui=4.0, est=3.274096920863915, details={'was_impossible': False}),
#  Prediction(uid='504', iid='187', r_ui=3.0, est=4.134457691789278, details={'was_impossible': False}),
#  Prediction(uid='436', iid='288', r_ui=4.0, est=3.789061967646794, details={'was_impossible': False}),
#  Prediction(uid='541', iid='1030', r_ui=3.0, est=2.4608208222008163, details={'was_impossible': False}),
#  Prediction(uid='551', iid='168', r_ui=5.0, est=4.615843857065728, details={'was_impossible': False}),
#  Prediction(uid='703', iid='15', r_ui=5.0, est=3.8150717557658704, details={'was_impossible': False}),
#  Prediction(uid='521', iid='228', r_ui=4.0, est=3.3327438282218824, details={'was_impossible': False}),
#  Prediction(uid='510', iid='325', r_ui=1.0, est=2.6172479425309425, details={'was_impossible': False}),
#  Prediction(uid='463', iid='689', r_ui=2.0, est=2.825575480539671, details={'was_impossible': False}),
#  Prediction(uid='312', iid='499', r_ui=4.0, est=4.532605191479615, details={'was_impossible': False}),
#  Prediction(uid='533', iid='357', r_ui=3.0, est=3.9518719273598726, details={'was_impossible': False}),
#  Prediction(uid='393', iid='794', r_ui=4.0, est=3.7518431667020558, details={'was_impossible': False}),
#  Prediction(uid='642', iid='748', r_ui=5.0, est=4.316071694486281, details={'was_impossible': False}),
#  Prediction(uid='851', iid='1291', r_ui=2.0, est=3.114738924132208, details={'was_impossible': False}),
#  Prediction(uid='128', iid='507', r_ui=4.0, est=4.245079521336779, details={'was_impossible': False}),
#  Prediction(uid='568', iid='653', r_ui=4.0, est=3.3345643898544672, details={'was_impossible': False}),
#  Prediction(uid='325', iid='1', r_ui=2.0, est=3.1237714293159202, details={'was_impossible': False}),
#  Prediction(uid='345', iid='161', r_ui=3.0, est=3.4454807639598855, details={'was_impossible': False}),
#  Prediction(uid='741', iid='280', r_ui=3.0, est=2.9506777636758974, details={'was_impossible': False}),
#  Prediction(uid='545', iid='222', r_ui=4.0, est=4.015111213363586, details={'was_impossible': False}),
#  Prediction(uid='778', iid='144', r_ui=4.0, est=3.1619073106527944, details={'was_impossible': False}),
#  Prediction(uid='874', iid='137', r_ui=4.0, est=3.9137096216866993, details={'was_impossible': False}),
#  Prediction(uid='897', iid='1254', r_ui=2.0, est=3.0425121014301513, details={'was_impossible': False}),
#  Prediction(uid='385', iid='1143', r_ui=4.0, est=3.9157984662600596, details={'was_impossible': False}),
#  Prediction(uid='487', iid='43', r_ui=3.0, est=3.0380445956370474, details={'was_impossible': False}),
#  Prediction(uid='425', iid='269', r_ui=4.0, est=3.4819212124671317, details={'was_impossible': False}),
#  Prediction(uid='758', iid='412', r_ui=5.0, est=3.1532181945684226, details={'was_impossible': False}),
#  Prediction(uid='313', iid='191', r_ui=5.0, est=4.338890435468557, details={'was_impossible': False}),
#  Prediction(uid='11', iid='414', r_ui=3.0, est=3.2709087822278593, details={'was_impossible': False}),
#  Prediction(uid='225', iid='1443', r_ui=4.0, est=3.9188893116349055, details={'was_impossible': False}),
#  Prediction(uid='849', iid='676', r_ui=5.0, est=4.296318457343889, details={'was_impossible': False}),
#  Prediction(uid='616', iid='339', r_ui=3.0, est=3.2622897612707495, details={'was_impossible': False}),
#  Prediction(uid='109', iid='131', r_ui=1.0, est=3.6268532123559494, details={'was_impossible': False}),
#  Prediction(uid='548', iid='164', r_ui=5.0, est=4.191120446404634, details={'was_impossible': False}),
#  Prediction(uid='455', iid='1034', r_ui=2.0, est=2.5883320133400347, details={'was_impossible': False}),
#  Prediction(uid='289', iid='849', r_ui=4.0, est=2.5314449836926034, details={'was_impossible': False}),
#  Prediction(uid='896', iid='148', r_ui=2.0, est=2.7121263813837246, details={'was_impossible': False}),
#  Prediction(uid='38', iid='294', r_ui=5.0, est=4.2363933487123395, details={'was_impossible': False}),
#  Prediction(uid='194', iid='385', r_ui=2.0, est=2.8784572036450906, details={'was_impossible': False}),
#  Prediction(uid='385', iid='235', r_ui=5.0, est=2.9257721550669773, details={'was_impossible': False}),
#  Prediction(uid='553', iid='131', r_ui=5.0, est=4.221925792583834, details={'was_impossible': False}),
#  Prediction(uid='896', iid='184', r_ui=3.0, est=2.544288994335659, details={'was_impossible': False}),
#  Prediction(uid='940', iid='315', r_ui=4.0, est=3.7518673990654245, details={'was_impossible': False}),
#  Prediction(uid='178', iid='144', r_ui=4.0, est=4.042026837362827, details={'was_impossible': False}),
#  Prediction(uid='482', iid='311', r_ui=4.0, est=3.652574853270122, details={'was_impossible': False}),
#  Prediction(uid='327', iid='663', r_ui=4.0, est=3.358329532783626, details={'was_impossible': False}),
#  Prediction(uid='601', iid='173', r_ui=5.0, est=3.2722410531348856, details={'was_impossible': False}),
#  Prediction(uid='345', iid='150', r_ui=5.0, est=3.964276805426854, details={'was_impossible': False}),
#  Prediction(uid='761', iid='1014', r_ui=1.0, est=3.2766214299907666, details={'was_impossible': False}),
#  Prediction(uid='790', iid='1119', r_ui=4.0, est=3.414139582418853, details={'was_impossible': False}),
#  Prediction(uid='489', iid='989', r_ui=3.0, est=3.650615075269587, details={'was_impossible': False}),
#  Prediction(uid='38', iid='318', r_ui=3.0, est=4.904403869003206, details={'was_impossible': False}),
#  Prediction(uid='279', iid='1496', r_ui=3.0, est=3.290928609429835, details={'was_impossible': False}),
#  Prediction(uid='923', iid='591', r_ui=5.0, est=4.382930769569598, details={'was_impossible': False}),
#  Prediction(uid='323', iid='215', r_ui=5.0, est=3.884844456898235, details={'was_impossible': False}),
#  Prediction(uid='376', iid='181', r_ui=4.0, est=3.968293155510788, details={'was_impossible': False}),
#  Prediction(uid='927', iid='541', r_ui=5.0, est=3.2852051757004355, details={'was_impossible': False}),
#  Prediction(uid='416', iid='1286', r_ui=5.0, est=3.7607078604926376, details={'was_impossible': False}),
#  Prediction(uid='268', iid='655', r_ui=4.0, est=3.232223071522958, details={'was_impossible': False}),
#  Prediction(uid='64', iid='196', r_ui=4.0, est=3.780537529540354, details={'was_impossible': False}),
#  Prediction(uid='271', iid='427', r_ui=5.0, est=4.533810513592149, details={'was_impossible': False}),
#  Prediction(uid='122', iid='511', r_ui=5.0, est=4.508428432519312, details={'was_impossible': False}),
#  Prediction(uid='167', iid='404', r_ui=3.0, est=3.550616613573643, details={'was_impossible': False}),
#  Prediction(uid='580', iid='281', r_ui=2.0, est=3.2860640152597558, details={'was_impossible': False}),
#  Prediction(uid='95', iid='510', r_ui=4.0, est=3.956199322456924, details={'was_impossible': False}),
#  Prediction(uid='615', iid='237', r_ui=4.0, est=3.8378133614450425, details={'was_impossible': False}),
#  Prediction(uid='663', iid='25', r_ui=4.0, est=3.242869496021389, details={'was_impossible': False}),
#  Prediction(uid='883', iid='517', r_ui=4.0, est=4.169018346925158, details={'was_impossible': False}),
#  Prediction(uid='189', iid='30', r_ui=4.0, est=4.487410582045024, details={'was_impossible': False}),
#  Prediction(uid='735', iid='333', r_ui=4.0, est=3.0362381599430686, details={'was_impossible': False}),
#  Prediction(uid='711', iid='272', r_ui=5.0, est=4.595484311881676, details={'was_impossible': False}),
#  Prediction(uid='874', iid='124', r_ui=4.0, est=3.911905131506932, details={'was_impossible': False}),
#  Prediction(uid='796', iid='525', r_ui=4.0, est=4.302836730067257, details={'was_impossible': False}),
#  Prediction(uid='668', iid='596', r_ui=3.0, est=3.3309687068328984, details={'was_impossible': False}),
#  Prediction(uid='533', iid='9', r_ui=4.0, est=3.088360562174387, details={'was_impossible': False}),
#  Prediction(uid='851', iid='248', r_ui=4.0, est=3.689896300037393, details={'was_impossible': False}),
#  Prediction(uid='360', iid='14', r_ui=5.0, est=4.295053356379111, details={'was_impossible': False}),
#  Prediction(uid='62', iid='181', r_ui=4.0, est=3.6489017770609116, details={'was_impossible': False}),
#  Prediction(uid='579', iid='514', r_ui=3.0, est=3.6071066805867447, details={'was_impossible': False}),
#  Prediction(uid='158', iid='745', r_ui=4.0, est=3.8932609021748665, details={'was_impossible': False}),
#  Prediction(uid='119', iid='1052', r_ui=4.0, est=2.8145476669323046, details={'was_impossible': False}),
#  Prediction(uid='275', iid='162', r_ui=3.0, est=3.0062637980299725, details={'was_impossible': False}),
#  Prediction(uid='503', iid='277', r_ui=4.0, est=3.550243667292547, details={'was_impossible': False}),
#  Prediction(uid='710', iid='496', r_ui=4.0, est=3.762865690797432, details={'was_impossible': False}),
#  Prediction(uid='660', iid='550', r_ui=2.0, est=2.53748582562455, details={'was_impossible': False}),
#  Prediction(uid='42', iid='151', r_ui=4.0, est=4.006603415366805, details={'was_impossible': False}),
#  Prediction(uid='479', iid='147', r_ui=3.0, est=3.136290358101404, details={'was_impossible': False}),
#  Prediction(uid='574', iid='887', r_ui=4.0, est=3.547386444578488, details={'was_impossible': False}),
#  Prediction(uid='13', iid='655', r_ui=5.0, est=3.4043510979857476, details={'was_impossible': False}),
#  Prediction(uid='593', iid='220', r_ui=3.0, est=3.5900800549198553, details={'was_impossible': False}),
#  Prediction(uid='524', iid='526', r_ui=3.0, est=3.6644888175026704, details={'was_impossible': False}),
#  Prediction(uid='244', iid='721', r_ui=5.0, est=3.8653843373077468, details={'was_impossible': False}),
#  Prediction(uid='774', iid='567', r_ui=1.0, est=1.61194699107705, details={'was_impossible': False}),
#  Prediction(uid='848', iid='132', r_ui=5.0, est=4.443800702498747, details={'was_impossible': False}),
#  Prediction(uid='851', iid='435', r_ui=4.0, est=4.1910910925059595, details={'was_impossible': False}),
#  Prediction(uid='198', iid='58', r_ui=3.0, est=3.476114920233524, details={'was_impossible': False}),
#  Prediction(uid='286', iid='210', r_ui=5.0, est=4.1479670119326055, details={'was_impossible': False}),
#  Prediction(uid='608', iid='753', r_ui=5.0, est=3.7117551338737425, details={'was_impossible': False}),
#  Prediction(uid='303', iid='379', r_ui=4.0, est=2.909965491075835, details={'was_impossible': False}),
#  Prediction(uid='271', iid='221', r_ui=3.0, est=3.5703304018158373, details={'was_impossible': False}),
#  Prediction(uid='492', iid='650', r_ui=2.0, est=2.955258406266812, details={'was_impossible': False}),
#  Prediction(uid='782', iid='1278', r_ui=4.0, est=2.9032695556084613, details={'was_impossible': False}),
#  Prediction(uid='864', iid='609', r_ui=3.0, est=3.7472811043916394, details={'was_impossible': False}),
#  Prediction(uid='763', iid='357', r_ui=4.0, est=4.399132320743798, details={'was_impossible': False}),
#  Prediction(uid='894', iid='45', r_ui=4.0, est=3.9545209691026315, details={'was_impossible': False}),
#  Prediction(uid='272', iid='201', r_ui=3.0, est=3.3352185512295622, details={'was_impossible': False}),
#  Prediction(uid='264', iid='275', r_ui=5.0, est=4.463787118774481, details={'was_impossible': False}),
#  Prediction(uid='286', iid='278', r_ui=5.0, est=3.3703633612163197, details={'was_impossible': False}),
#  Prediction(uid='190', iid='508', r_ui=3.0, est=3.251103651337618, details={'was_impossible': False}),
#  Prediction(uid='80', iid='194', r_ui=3.0, est=4.227434978469828, details={'was_impossible': False}),
#  Prediction(uid='916', iid='222', r_ui=3.0, est=2.7510675535287357, details={'was_impossible': False}),
#  Prediction(uid='532', iid='495', r_ui=4.0, est=4.328629399704472, details={'was_impossible': False}),
#  Prediction(uid='929', iid='136', r_ui=3.0, est=3.8101903332903944, details={'was_impossible': False}),
#  Prediction(uid='178', iid='731', r_ui=4.0, est=3.3958711670855513, details={'was_impossible': False}),
#  Prediction(uid='327', iid='537', r_ui=4.0, est=3.395426055941821, details={'was_impossible': False}),
#  Prediction(uid='591', iid='172', r_ui=3.0, est=4.168098181175173, details={'was_impossible': False}),
#  Prediction(uid='679', iid='268', r_ui=4.0, est=3.5417606794984597, details={'was_impossible': False}),
#  Prediction(uid='795', iid='429', r_ui=3.0, est=3.48001150610376, details={'was_impossible': False}),
#  Prediction(uid='234', iid='321', r_ui=2.0, est=2.4697946723826156, details={'was_impossible': False}),
#  Prediction(uid='698', iid='275', r_ui=4.0, est=3.117389126989491, details={'was_impossible': False}),
#  Prediction(uid='385', iid='503', r_ui=3.0, est=3.187324431265722, details={'was_impossible': False}),
#  Prediction(uid='268', iid='746', r_ui=3.0, est=3.0337159735891586, details={'was_impossible': False}),
#  Prediction(uid='682', iid='774', r_ui=4.0, est=2.9691277280423387, details={'was_impossible': False}),
#  Prediction(uid='244', iid='287', r_ui=3.0, est=4.046864780632235, details={'was_impossible': False}),
#  Prediction(uid='387', iid='175', r_ui=5.0, est=3.9351449029664476, details={'was_impossible': False}),
#  Prediction(uid='707', iid='194', r_ui=4.0, est=3.7088947911633205, details={'was_impossible': False}),
#  Prediction(uid='216', iid='189', r_ui=3.0, est=4.091719885091441, details={'was_impossible': False}),
#  Prediction(uid='524', iid='523', r_ui=4.0, est=3.884540184516297, details={'was_impossible': False}),
#  Prediction(uid='486', iid='288', r_ui=4.0, est=3.026911412643544, details={'was_impossible': False}),
#  Prediction(uid='395', iid='252', r_ui=3.0, est=3.263464005097506, details={'was_impossible': False}),
#  Prediction(uid='620', iid='78', r_ui=4.0, est=3.146443180327241, details={'was_impossible': False}),
#  Prediction(uid='892', iid='64', r_ui=4.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='345', iid='241', r_ui=4.0, est=3.6034091283688197, details={'was_impossible': False}),
#  Prediction(uid='593', iid='597', r_ui=2.0, est=3.600039514428148, details={'was_impossible': False}),
#  Prediction(uid='895', iid='1', r_ui=4.0, est=3.9709831066148755, details={'was_impossible': False}),
#  Prediction(uid='18', iid='237', r_ui=3.0, est=3.4799160567197593, details={'was_impossible': False}),
#  Prediction(uid='60', iid='151', r_ui=5.0, est=3.87921657245408, details={'was_impossible': False}),
#  Prediction(uid='417', iid='39', r_ui=3.0, est=2.824126646495435, details={'was_impossible': False}),
#  Prediction(uid='823', iid='721', r_ui=4.0, est=3.7844600883126684, details={'was_impossible': False}),
#  Prediction(uid='286', iid='231', r_ui=3.0, est=3.0143216158906734, details={'was_impossible': False}),
#  Prediction(uid='389', iid='47', r_ui=4.0, est=3.748772825376252, details={'was_impossible': False}),
#  Prediction(uid='298', iid='1142', r_ui=4.0, est=4.2186660937449805, details={'was_impossible': False}),
#  Prediction(uid='216', iid='200', r_ui=5.0, est=4.031438014556669, details={'was_impossible': False}),
#  Prediction(uid='236', iid='204', r_ui=3.0, est=3.7388379101212545, details={'was_impossible': False}),
#  Prediction(uid='393', iid='808', r_ui=4.0, est=3.239206843281746, details={'was_impossible': False}),
#  Prediction(uid='704', iid='354', r_ui=4.0, est=3.4033619941744373, details={'was_impossible': False}),
#  Prediction(uid='416', iid='1189', r_ui=5.0, est=4.117010651127118, details={'was_impossible': False}),
#  Prediction(uid='349', iid='696', r_ui=3.0, est=3.1452111170048673, details={'was_impossible': False}),
#  Prediction(uid='90', iid='174', r_ui=5.0, est=4.416824326316604, details={'was_impossible': False}),
#  Prediction(uid='828', iid='1466', r_ui=4.0, est=3.1107487924659134, details={'was_impossible': False}),
#  Prediction(uid='286', iid='1239', r_ui=3.0, est=2.9541599277489143, details={'was_impossible': False}),
#  Prediction(uid='279', iid='275', r_ui=3.0, est=3.6359640022030617, details={'was_impossible': False}),
#  Prediction(uid='451', iid='322', r_ui=4.0, est=3.245161493004979, details={'was_impossible': False}),
#  Prediction(uid='405', iid='959', r_ui=1.0, est=1.812354932465408, details={'was_impossible': False}),
#  Prediction(uid='718', iid='815', r_ui=4.0, est=3.4636378510298647, details={'was_impossible': False}),
# ...
#  Prediction(uid='264', iid='672', r_ui=3.0, est=2.9181076600929106, details={'was_impossible': False}),
#  Prediction(uid='405', iid='48', r_ui=1.0, est=2.537684338510401, details={'was_impossible': False}),
#  Prediction(uid='429', iid='961', r_ui=3.0, est=3.7190538416773404, details={'was_impossible': False}),
#  Prediction(uid='215', iid='164', r_ui=3.0, est=3.871906241228528, details={'was_impossible': False}),
#  Prediction(uid='569', iid='340', r_ui=4.0, est=3.4445303474301427, details={'was_impossible': False}),
#  Prediction(uid='621', iid='804', r_ui=4.0, est=3.4596287213935653, details={'was_impossible': False}),
#  Prediction(uid='188', iid='22', r_ui=5.0, est=4.440820704886493, details={'was_impossible': False}),
#  Prediction(uid='360', iid='144', r_ui=2.0, est=3.9317952011654898, details={'was_impossible': False}),
#  Prediction(uid='293', iid='132', r_ui=4.0, est=3.699655291242002, details={'was_impossible': False}),
#  Prediction(uid='399', iid='343', r_ui=2.0, est=2.642413163070678, details={'was_impossible': False}),
#  Prediction(uid='456', iid='86', r_ui=2.0, est=3.84564858216218, details={'was_impossible': False}),
#  Prediction(uid='407', iid='157', r_ui=2.0, est=3.504134843392441, details={'was_impossible': False}),
#  Prediction(uid='707', iid='100', r_ui=5.0, est=4.218180492240942, details={'was_impossible': False}),
#  Prediction(uid='328', iid='750', r_ui=4.0, est=3.9697182693151865, details={'was_impossible': False}),
#  Prediction(uid='488', iid='173', r_ui=4.0, est=3.500923149720396, details={'was_impossible': False}),
#  Prediction(uid='868', iid='229', r_ui=3.0, est=2.3569396588078146, details={'was_impossible': False}),
#  Prediction(uid='151', iid='531', r_ui=3.0, est=4.079382968409575, details={'was_impossible': False}),
#  Prediction(uid='848', iid='523', r_ui=5.0, est=4.8034949408239305, details={'was_impossible': False}),
#  Prediction(uid='454', iid='95', r_ui=2.0, est=3.7728155906644374, details={'was_impossible': False}),
#  Prediction(uid='368', iid='7', r_ui=4.0, est=3.8262575981878104, details={'was_impossible': False}),
#  Prediction(uid='807', iid='526', r_ui=5.0, est=4.052807826370831, details={'was_impossible': False}),
#  Prediction(uid='708', iid='15', r_ui=3.0, est=3.7288797120073984, details={'was_impossible': False}),
#  Prediction(uid='845', iid='904', r_ui=3.0, est=3.0418453802005523, details={'was_impossible': False}),
#  Prediction(uid='658', iid='471', r_ui=4.0, est=3.3483967920059774, details={'was_impossible': False}),
#  Prediction(uid='328', iid='194', r_ui=3.0, est=3.8777503995421028, details={'was_impossible': False}),
#  Prediction(uid='663', iid='473', r_ui=3.0, est=3.068030383598203, details={'was_impossible': False}),
#  Prediction(uid='537', iid='523', r_ui=3.0, est=3.4082437138942696, details={'was_impossible': False}),
#  Prediction(uid='323', iid='1012', r_ui=4.0, est=3.616463848208992, details={'was_impossible': False}),
#  Prediction(uid='92', iid='834', r_ui=1.0, est=2.4749398380542207, details={'was_impossible': False}),
#  Prediction(uid='161', iid='582', r_ui=1.0, est=2.189606839787603, details={'was_impossible': False}),
#  Prediction(uid='198', iid='568', r_ui=3.0, est=3.0432629732618874, details={'was_impossible': False}),
#  Prediction(uid='650', iid='429', r_ui=4.0, est=3.5418568767543994, details={'was_impossible': False}),
#  Prediction(uid='776', iid='708', r_ui=5.0, est=3.4255967779887997, details={'was_impossible': False}),
#  Prediction(uid='617', iid='320', r_ui=5.0, est=2.9581747039662867, details={'was_impossible': False}),
#  Prediction(uid='843', iid='121', r_ui=3.0, est=3.103592545998013, details={'was_impossible': False}),
#  Prediction(uid='196', iid='173', r_ui=2.0, est=3.9377500402966255, details={'was_impossible': False}),
#  Prediction(uid='37', iid='273', r_ui=3.0, est=3.8714123140564647, details={'was_impossible': False}),
#  Prediction(uid='402', iid='410', r_ui=1.0, est=3.4033876535184993, details={'was_impossible': False}),
#  Prediction(uid='487', iid='1', r_ui=5.0, est=4.1557358074803625, details={'was_impossible': False}),
#  Prediction(uid='133', iid='750', r_ui=4.0, est=3.674685937152186, details={'was_impossible': False}),
#  Prediction(uid='123', iid='23', r_ui=4.0, est=4.238157104875643, details={'was_impossible': False}),
#  Prediction(uid='788', iid='1248', r_ui=3.0, est=2.946666910193069, details={'was_impossible': False}),
#  Prediction(uid='606', iid='1280', r_ui=2.0, est=3.301744794987854, details={'was_impossible': False}),
#  Prediction(uid='151', iid='181', r_ui=5.0, est=3.93837719908583, details={'was_impossible': False}),
#  Prediction(uid='305', iid='338', r_ui=3.0, est=2.57823955062355, details={'was_impossible': False}),
#  Prediction(uid='889', iid='297', r_ui=3.0, est=3.774685352328312, details={'was_impossible': False}),
#  Prediction(uid='253', iid='294', r_ui=4.0, est=3.4929122411105, details={'was_impossible': False}),
#  Prediction(uid='553', iid='191', r_ui=4.0, est=4.463866770861655, details={'was_impossible': False}),
#  Prediction(uid='409', iid='1541', r_ui=4.0, est=3.09915343867288, details={'was_impossible': False}),
#  Prediction(uid='285', iid='150', r_ui=5.0, est=3.8199834641940926, details={'was_impossible': False}),
#  Prediction(uid='77', iid='268', r_ui=5.0, est=3.2226325567312553, details={'was_impossible': False}),
#  Prediction(uid='455', iid='1137', r_ui=3.0, est=3.80123348511968, details={'was_impossible': False}),
#  Prediction(uid='483', iid='313', r_ui=2.0, est=4.0155353412323675, details={'was_impossible': False}),
#  Prediction(uid='84', iid='15', r_ui=4.0, est=4.240628617689419, details={'was_impossible': False}),
#  Prediction(uid='709', iid='739', r_ui=3.0, est=3.329974966951749, details={'was_impossible': False}),
#  Prediction(uid='579', iid='7', r_ui=3.0, est=3.353437643797254, details={'was_impossible': False}),
#  Prediction(uid='327', iid='709', r_ui=4.0, est=4.1674883175826105, details={'was_impossible': False}),
#  Prediction(uid='805', iid='405', r_ui=3.0, est=2.669219549445386, details={'was_impossible': False}),
#  Prediction(uid='786', iid='86', r_ui=4.0, est=3.987517716022586, details={'was_impossible': False}),
#  Prediction(uid='334', iid='301', r_ui=2.0, est=3.5050675097899804, details={'was_impossible': False}),
#  Prediction(uid='388', iid='773', r_ui=3.0, est=3.591972730177405, details={'was_impossible': False}),
#  Prediction(uid='222', iid='1419', r_ui=1.0, est=2.3562560712498453, details={'was_impossible': False}),
#  Prediction(uid='151', iid='433', r_ui=3.0, est=4.226491285764357, details={'was_impossible': False}),
#  Prediction(uid='556', iid='187', r_ui=5.0, est=4.548340344493748, details={'was_impossible': False}),
#  Prediction(uid='850', iid='490', r_ui=5.0, est=4.265673515910254, details={'was_impossible': False}),
#  Prediction(uid='291', iid='41', r_ui=4.0, est=3.6391507584808847, details={'was_impossible': False}),
#  Prediction(uid='846', iid='739', r_ui=4.0, est=3.2495209685601534, details={'was_impossible': False}),
#  Prediction(uid='332', iid='97', r_ui=5.0, est=4.4189272830923745, details={'was_impossible': False}),
#  Prediction(uid='388', iid='307', r_ui=4.0, est=4.046850872584299, details={'was_impossible': False}),
#  Prediction(uid='776', iid='134', r_ui=4.0, est=4.008788395684908, details={'was_impossible': False}),
#  Prediction(uid='642', iid='955', r_ui=3.0, est=3.6344904856127322, details={'was_impossible': False}),
#  Prediction(uid='622', iid='402', r_ui=3.0, est=3.3637642243109194, details={'was_impossible': False}),
#  Prediction(uid='890', iid='436', r_ui=3.0, est=3.531018100195569, details={'was_impossible': False}),
#  Prediction(uid='269', iid='640', r_ui=5.0, est=2.624229132681333, details={'was_impossible': False}),
#  Prediction(uid='6', iid='32', r_ui=4.0, est=3.9557920465526673, details={'was_impossible': False}),
#  Prediction(uid='313', iid='155', r_ui=2.0, est=2.98033671175361, details={'was_impossible': False}),
#  Prediction(uid='417', iid='452', r_ui=2.0, est=2.6964383732525965, details={'was_impossible': False}),
#  Prediction(uid='685', iid='299', r_ui=2.0, est=1.905887328377644, details={'was_impossible': False}),
#  Prediction(uid='469', iid='64', r_ui=5.0, est=4.882851375012729, details={'was_impossible': False}),
#  Prediction(uid='806', iid='455', r_ui=3.0, est=3.305908328968621, details={'was_impossible': False}),
#  Prediction(uid='370', iid='64', r_ui=4.0, est=4.2146263651668106, details={'was_impossible': False}),
#  Prediction(uid='313', iid='582', r_ui=2.0, est=3.954557117333818, details={'was_impossible': False}),
#  Prediction(uid='303', iid='873', r_ui=3.0, est=2.988623374954886, details={'was_impossible': False}),
#  Prediction(uid='363', iid='39', r_ui=4.0, est=2.8593430634479313, details={'was_impossible': False}),
#  Prediction(uid='882', iid='756', r_ui=3.0, est=3.161786319660346, details={'was_impossible': False}),
#  Prediction(uid='466', iid='909', r_ui=5.0, est=3.5101361705046163, details={'was_impossible': False}),
#  Prediction(uid='59', iid='25', r_ui=4.0, est=3.867524993698741, details={'was_impossible': False}),
#  Prediction(uid='186', iid='588', r_ui=4.0, est=3.926682999170905, details={'was_impossible': False}),
#  Prediction(uid='735', iid='288', r_ui=4.0, est=2.725167778982937, details={'was_impossible': False}),
#  Prediction(uid='52', iid='288', r_ui=3.0, est=3.7676648830167005, details={'was_impossible': False}),
#  Prediction(uid='624', iid='255', r_ui=3.0, est=3.6032875194258347, details={'was_impossible': False}),
#  Prediction(uid='868', iid='378', r_ui=2.0, est=3.1191039427296317, details={'was_impossible': False}),
#  Prediction(uid='847', iid='367', r_ui=3.0, est=3.2149414537413112, details={'was_impossible': False}),
#  Prediction(uid='675', iid='347', r_ui=4.0, est=3.311539656994626, details={'was_impossible': False}),
#  Prediction(uid='210', iid='97', r_ui=5.0, est=4.368870991088446, details={'was_impossible': False}),
#  Prediction(uid='929', iid='654', r_ui=3.0, est=4.11917654922281, details={'was_impossible': False}),
#  Prediction(uid='631', iid='307', r_ui=4.0, est=3.246744625058385, details={'was_impossible': False}),
#  Prediction(uid='72', iid='382', r_ui=4.0, est=3.482241462647438, details={'was_impossible': False}),
#  Prediction(uid='276', iid='77', r_ui=3.0, est=3.452134140753811, details={'was_impossible': False}),
#  Prediction(uid='459', iid='286', r_ui=4.0, est=3.166680411310893, details={'was_impossible': False}),
#  Prediction(uid='727', iid='421', r_ui=5.0, est=3.188706114715923, details={'was_impossible': False}),
#  Prediction(uid='75', iid='137', r_ui=4.0, est=3.5222636568493324, details={'was_impossible': False}),
#  Prediction(uid='486', iid='327', r_ui=3.0, est=3.1936408972374535, details={'was_impossible': False}),
#  Prediction(uid='882', iid='432', r_ui=5.0, est=4.028534785776878, details={'was_impossible': False}),
#  Prediction(uid='919', iid='1284', r_ui=3.0, est=2.7449302407438605, details={'was_impossible': False}),
#  Prediction(uid='149', iid='310', r_ui=2.0, est=2.984645558836911, details={'was_impossible': False}),
#  Prediction(uid='5', iid='454', r_ui=1.0, est=2.7514847614404547, details={'was_impossible': False}),
#  Prediction(uid='548', iid='466', r_ui=5.0, est=3.5178403585743303, details={'was_impossible': False}),
#  Prediction(uid='546', iid='977', r_ui=5.0, est=3.3311819313316398, details={'was_impossible': False}),
#  Prediction(uid='87', iid='196', r_ui=5.0, est=4.369331700895697, details={'was_impossible': False}),
#  Prediction(uid='847', iid='1', r_ui=3.0, est=3.1755189639580923, details={'was_impossible': False}),
#  Prediction(uid='579', iid='88', r_ui=4.0, est=3.342760212143559, details={'was_impossible': False}),
#  Prediction(uid='345', iid='956', r_ui=4.0, est=3.7923862020013166, details={'was_impossible': False}),
#  Prediction(uid='327', iid='715', r_ui=4.0, est=3.1098075916794277, details={'was_impossible': False}),
#  Prediction(uid='234', iid='1221', r_ui=4.0, est=3.0499365072105618, details={'was_impossible': False}),
#  Prediction(uid='854', iid='479', r_ui=4.0, est=3.8534862661937628, details={'was_impossible': False}),
#  Prediction(uid='807', iid='566', r_ui=4.0, est=3.9040155581088207, details={'was_impossible': False}),
#  Prediction(uid='396', iid='472', r_ui=5.0, est=3.5214774918529503, details={'was_impossible': False}),
#  Prediction(uid='719', iid='79', r_ui=4.0, est=3.8911746338501194, details={'was_impossible': False}),
#  Prediction(uid='312', iid='740', r_ui=4.0, est=4.477646274465528, details={'was_impossible': False}),
#  Prediction(uid='436', iid='785', r_ui=2.0, est=3.6651694532383026, details={'was_impossible': False}),
#  Prediction(uid='592', iid='881', r_ui=1.0, est=2.7639582837401595, details={'was_impossible': False}),
#  Prediction(uid='624', iid='886', r_ui=4.0, est=3.0978893050986196, details={'was_impossible': False}),
#  Prediction(uid='916', iid='2', r_ui=3.0, est=3.047285356914539, details={'was_impossible': False}),
#  Prediction(uid='95', iid='71', r_ui=5.0, est=4.150847170859132, details={'was_impossible': False}),
#  Prediction(uid='262', iid='567', r_ui=1.0, est=2.642280327345366, details={'was_impossible': False}),
#  Prediction(uid='606', iid='168', r_ui=5.0, est=4.145364720916449, details={'was_impossible': False}),
#  Prediction(uid='398', iid='235', r_ui=2.0, est=2.641428036493212, details={'was_impossible': False}),
#  Prediction(uid='321', iid='215', r_ui=3.0, est=3.3966497341167066, details={'was_impossible': False}),
#  Prediction(uid='686', iid='2', r_ui=3.0, est=3.69427146665832, details={'was_impossible': False}),
#  Prediction(uid='619', iid='879', r_ui=4.0, est=3.26475721831454, details={'was_impossible': False}),
#  Prediction(uid='932', iid='659', r_ui=5.0, est=4.432928989947107, details={'was_impossible': False}),
#  Prediction(uid='308', iid='275', r_ui=4.0, est=3.9269295536653965, details={'was_impossible': False}),
#  Prediction(uid='782', iid='1241', r_ui=2.0, est=2.690110711690815, details={'was_impossible': False}),
#  Prediction(uid='351', iid='751', r_ui=4.0, est=4.13953598438369, details={'was_impossible': False}),
#  Prediction(uid='269', iid='661', r_ui=4.0, est=3.4658936767511754, details={'was_impossible': False}),
#  Prediction(uid='93', iid='118', r_ui=3.0, est=3.7188507469677186, details={'was_impossible': False}),
#  Prediction(uid='425', iid='823', r_ui=3.0, est=2.3519992193449006, details={'was_impossible': False}),
#  Prediction(uid='524', iid='310', r_ui=4.0, est=3.4926604563479575, details={'was_impossible': False}),
#  Prediction(uid='618', iid='371', r_ui=3.0, est=2.801706268623488, details={'was_impossible': False}),
#  Prediction(uid='268', iid='182', r_ui=4.0, est=3.816185563254765, details={'was_impossible': False}),
#  Prediction(uid='324', iid='538', r_ui=4.0, est=4.229595160632899, details={'was_impossible': False}),
#  Prediction(uid='899', iid='740', r_ui=5.0, est=3.4254944750682674, details={'was_impossible': False}),
#  Prediction(uid='87', iid='80', r_ui=4.0, est=3.2206051754460363, details={'was_impossible': False}),
#  Prediction(uid='825', iid='925', r_ui=4.0, est=3.6023257222354466, details={'was_impossible': False}),
#  Prediction(uid='378', iid='272', r_ui=4.0, est=3.910579797501628, details={'was_impossible': False}),
#  Prediction(uid='774', iid='135', r_ui=3.0, est=3.0782696906220948, details={'was_impossible': False}),
#  Prediction(uid='930', iid='238', r_ui=4.0, est=2.705155150543392, details={'was_impossible': False}),
#  Prediction(uid='704', iid='604', r_ui=5.0, est=4.1013770130387295, details={'was_impossible': False}),
#  Prediction(uid='854', iid='509', r_ui=4.0, est=3.6656480405259977, details={'was_impossible': False}),
#  Prediction(uid='704', iid='185', r_ui=4.0, est=3.839799631978268, details={'was_impossible': False}),
#  Prediction(uid='497', iid='1407', r_ui=3.0, est=2.717893422684282, details={'was_impossible': False}),
#  Prediction(uid='429', iid='166', r_ui=5.0, est=4.002847497337744, details={'was_impossible': False}),
#  Prediction(uid='255', iid='597', r_ui=4.0, est=2.278532872643299, details={'was_impossible': False}),
#  Prediction(uid='406', iid='136', r_ui=4.0, est=4.110283836603002, details={'was_impossible': False}),
#  ...]

# %% [markdown]
# ## Evaluation

# %%
from surprise import accuracy

accuracy.rmse(predictions=predictions)
# Out:
# RMSE: 0.9350
# 0.9350316172478067

# %%
accuracy.mae(predictions=predictions)
# Out:
# MAE:  0.7377
# 0.7377047556566634

# %% [markdown]
# # Cross validation

# %%
from surprise.model_selection import cross_validate

cross_validate(model, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9401  0.9307  0.9316  0.9381  0.9355  0.9352  0.0036
# MAE (testset)     0.7414  0.7320  0.7364  0.7394  0.7375  0.7373  0.0031
# Fit time          3.65    3.63    3.59    3.60    3.59    3.61    0.03
# Test time         0.14    0.10    0.13    0.13    0.10    0.12    0.02
# {'test_rmse': array([0.94013013, 0.9306818 , 0.93155582, 0.93810254, 0.93554429]),
#  'test_mae': array([0.7413599 , 0.7320472 , 0.73638252, 0.73939694, 0.73747982]),
#  'fit_time': (3.6541028022766113,
#   3.6313018798828125,
#   3.5908095836639404,
#   3.5965473651885986,
#   3.5859591960906982),
#  'test_time': (0.13564324378967285,
#   0.09873199462890625,
#   0.1326453685760498,
#   0.13463926315307617,
#   0.09778022766113281)}
