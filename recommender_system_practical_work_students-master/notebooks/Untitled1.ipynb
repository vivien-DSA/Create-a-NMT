# %%
import pandas as pd
from pathlib import Path
from surprise import Dataset
from surprise import Reader
DATA_DIR = Path('../data/movielens/')

reader = Reader(line_format='user item rating timestamp', sep=',', skip_lines=1)

ratings100k = Dataset.load_from_file(DATA_DIR / 'ml-100k/ratings.csv', reader=reader)
ratings100k = Dataset.load_from_file(DATA_DIR / 'ml-latest-small/ratings.csv', reader=reader)


movies = pd.read_csv(DATA_DIR / 'movies.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-73b675533eb6> in <module>
#       7 reader = Reader(line_format='user item rating timestamp', sep=',', skip_lines=1)
#       8
# ----> 9 ratings100k = Dataset.load_from_file(DATA_DIR / 'ml-100k/ratings.csv', reader=reader)
#      10 ratings100k = Dataset.load_from_file(DATA_DIR / 'ml-latest-small/ratings.csv', reader=reader)
#      11
#
# ~\anaconda3\envs\recsys\lib\site-packages\surprise\dataset.py in load_from_file(cls, file_path, reader)
#     118         """
#     119
# --> 120         return DatasetAutoFolds(ratings_file=file_path, reader=reader)
#     121
#     122     @classmethod
#
# ~\anaconda3\envs\recsys\lib\site-packages\surprise\dataset.py in __init__(self, ratings_file, reader, df)
#     251         if ratings_file is not None:
#     252             self.ratings_file = ratings_file
# --> 253             self.raw_ratings = self.read_ratings(self.ratings_file)
#     254         elif df is not None:
#     255             self.df = df
#
# ~\anaconda3\envs\recsys\lib\site-packages\surprise\dataset.py in read_ratings(self, file_name)
#     168         file_name"""
#     169
# --> 170         with open(os.path.expanduser(file_name)) as f:
#     171             raw_ratings = [self.reader.parse_line(line) for line in
#     172                            itertools.islice(f, self.reader.skip_lines, None)]
#
# FileNotFoundError: [Errno 2] No such file or directory: '..\\data\\movielens\\ml-100k\\ratings.csv'
